# %%
import torch
import encoderDecoder
import torchvision.transforms as transforms
from dataset import get_loader
# Out:
# -----Loading vocabulary from vocab.pkl file!----
# ----Vocabulary successfully loaded from vocab.pkl file!---
# -----Loading vocabulary from vocab.pkl file!----
# ----Vocabulary successfully loaded from vocab.pkl file!---

# %%
transform = transforms.Compose(
        [
            transforms.Resize((256, 256)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
        ]
    )

val_dataset, val_loader = get_loader(
        root_folder="../data/flickr8k/Images",
        captions_file="../data/flickr8k/captions_val.txt",
        batch_size = 16,
        transform=transform,
        num_workers=1,
        split_type='val'
    )
# Out:
# -----Loading vocabulary from vocab.pkl file!----
# ----Vocabulary successfully loaded from vocab.pkl file!---
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# -----Loading vocabulary from vocab.pkl file!----
# ----Vocabulary successfully loaded from vocab.pkl file!---

# %%
device = "cuda" if torch.cuda.is_available() else \
         ("mps" if torch.backends.mps.is_available() else "cpu" ) 
#device = 'cpu'
print(device)
# Out:
# cuda

# %%
def indices_to_words(indices, vocab, referenceCorpus):
    decoded_sentences = []
    count = 0 ; 
    for idx_row in indices:
        count += 1 
        sentence = []
    
        for idx in idx_row:
            word = vocab.get_word(idx.item())
            if(word == '<start>'):
                continue 
            if word == '<end>':  # Stop decoding if '<end>' token is encountered
                break
            sentence.append(word)
        if(referenceCorpus):
            corpus = []
            corpus.append(sentence)
            decoded_sentences.append(corpus)
        else: 
            decoded_sentences.append(sentence)
    # print("the loop runs for" , count)
    return decoded_sentences

def generate_caption(imgs, caption, model):
    pred, alpha = model(imgs, caption)
    pred = pred.argmax(2)
    return indices_to_words(pred, val_dataset.vocab, False)
    
model = encoderDecoder.EncoderDecoderAttention(256, 256, len(val_dataset.vocab))
print(model.load_state_dict(torch.load("../model/model_epoch10.pth")))
model = model.to(device)
# Out:
# <All keys matched successfully>

# %%
predictions = []
ground_truth = []
topn = -1
log_interval = 50
with torch.no_grad():
    for batch_idx, (imgs, captions, all_captions) in enumerate(val_loader):
        if batch_idx % log_interval == 0 and batch_idx > 0:
            print('Batch:',batch_idx)
        imgs, captions = imgs.to(device), captions.to(device)
        preds = generate_caption(imgs, captions, model)
        truth = indices_to_words(captions, val_dataset.vocab, False)
        predictions.extend(preds)
        ground_truth.extend(truth)
        if topn != -1 and batch_idx == topn:
            break
# Out:
# Batch: 50
# Batch: 100
# Batch: 150
# Batch: 200
# Batch: 250
# Batch: 300
# Batch: 350

# %%
pred_captions = [' '.join(p) for p in predictions]
true_captions = [' '.join(g) for g in ground_truth]

# %%
pred_captions
# Out:
# ['a little is standing on a',
#  'a is a woman in . a red . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a people are playing on a skateboard . . the . . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a people are in',
#  'a man man in a white on a field . a . .',
#  'a dogs playing in a the field . . a . .',
#  'a dog is a snow . a green . . the mouth .',
#  'a little in in a in a the red . .',
#  'a young in a and in in running on the field .',
#  'a dog and is in ball . a . .',
#  'a man is in a and white . . a mouth .',
#  'a people is a in a .',
#  'a black dog running a black dog . a mouth . a . the grass . .',
#  'a people are',
#  'a man is a and standing a trick . . a a a . . .',
#  'a young in a red shirt in standing a man . a red . .',
#  'a man is in a a and in',
#  'a young is a boy in a red girl in in a grass .',
#  'a dog dog white dog is a black dog . a white . a mouth . a beach . .',
#  'a man is a',
#  'a in a people are a . . in a . . .',
#  'a man girl in a blue in . in . a grass . a in a .',
#  'a in people men in in in the grass . the . . .',
#  'a a girl in in a red . a . man . . a .',
#  'a is in the snow . .',
#  'a man and in a red and . a',
#  'a brown dog is in a and .',
#  'a people are a and on a red . .',
#  'a dog dog dog is running on the grass .',
#  'a dogs are in a water . a ball .',
#  'a dogs are <pad> the ball . a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in in man of a man in a air of',
#  'a black dog is running in a water . a beach .',
#  'a are playing a a blue . a .',
#  'a man is a the in a water . .',
#  'a man and is on a beach . .',
#  'a white is in in . the . .',
#  'a man with a red shirt is a a black is a red . a large . .',
#  'a men are are playing in and in running a and air . a and',
#  'a boy is a orange and is on a red . a bike . a white . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is on a air . a man in . . .',
#  'a in man are on a a . .',
#  'a boy is a orange and in the water .',
#  'a person is is on a air . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young are in a blue . a green in . the water .',
#  'a man is a a in a .',
#  'a boy boy in a a air . a ball . .',
#  'a dog dog white dog is a dog and in',
#  'a children are playing in a man in white in a . a .',
#  'a in in a',
#  'a young is in red in',
#  'a dog is a the . .',
#  'a people are on the skateboard of a white . a .',
#  'a children in on',
#  'a boy in on a water . a in on . the of a . .',
#  'a man dog is and a red . . a air .',
#  'a man is in sitting in a the snow .',
#  'a girl in a red and is a a . a .',
#  'a man of people are playing the snow .',
#  'a people people a man of a air .',
#  'a woman boy is in a ball .',
#  'a in on a on a . . a grass .',
#  'a man is a red . a a .',
#  'a girls girls are in a and . a large . a of a . .',
#  'a man in a a bike .',
#  'a in a in on a grass .',
#  'a dogs dogs dogs are on a grassy . .',
#  'a young in in a red shirt and a black .',
#  'a woman of people are are on in on a . . .',
#  'a boy in a red shirt is white shirt is running a .',
#  'a black dog dog in a a orange .',
#  'a young in a blue shirt white and and a white in a . .',
#  'a dogs dogs white dog are through the grass . .',
#  'a people are and in at a and street . .',
#  'a dog dog is running a white in a .',
#  'a little girl in on on the ball ball . a ball . . . .',
#  'a man and a orange . a man shirt white dog . . .',
#  'a man is a blue shirt and standing on a on . a a . . a the . . . .',
#  'a man is a black . a large . . the air . .',
#  'a people people are in a man in a red and .',
#  'a children boy in a a and on a rock .',
#  'a men are in a man . .',
#  'a people are playing a of a a grass .',
#  'a dog is a brown dog in a ball . .',
#  'a man in running on a water in a orange . .',
#  'a in a in a white a with a dog . in .',
#  'a man is on on mountain . . . .',
#  'a man in a blue shirt is a shirt is a of on a a',
#  'a man of people are on a man . .',
#  'a people are a man . . a camera . a and a of . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a woman boy is a a . a a the air . a shirt .',
#  'a man in a man in a man in a a . a . in a blue in .',
#  'a children are in a grass . a . a beach . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog dog is running in a water . the field dog . the . . ball . the mouth .',
#  'a man is a blue of is on ball . .',
#  'a man is a the field . a in . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a brown dog is running in a water . a water . . a in . .',
#  'a man is a red shirt and a blue . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a people in in a air . . . . a street . a street of .',
#  'a dog dog is a a grass . .',
#  'a man in running in the water of to a . .',
#  'a little is jumping a water in the water . .',
#  'a people girls are on a man . . . .',
#  'a woman in in a man . .',
#  'a little is a shirt is a air .',
#  'a man is on the air .',
#  'a man is in standing a blue is a a shirt .',
#  'a dog dog is in the snow . a large .',
#  'a person is is standing a a air . a of . a . .',
#  'a people are a red and on a . . . .',
#  'a young in a a a a a white with . the mouth .',
#  'a man in a red shirt and . to a red . .',
#  'a man dog in a large .',
#  'a boy girls in a . a . a air . a a red girl in a a . the background .',
#  'a girl boy is running in a a on .',
#  'a man man is a a rock of . . a large in in the snow . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in on a blue .',
#  'a is in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a blue shirt is a . on a street .',
#  'a man man a man is a blue on a air .',
#  'a dogs dogs are in the snow .',
#  'a girl in a shirt and standing a a a man . . .',
#  'a woman girl in standing on in in the . a . . .',
#  'a dogs dogs are white dog dog running the in .',
#  'a man in a red shirt in a red .',
#  'a dog dog is through the grass .',
#  'a are a on man . in a man . .',
#  'a man man in on in bike . a the water .',
#  'a people are in a red . in a . . .',
#  'a brown are in a . .',
#  'a people are on a of a rock .',
#  'a man is jumping a on a air . a . . skateboard .',
#  'a people in a red in . . . a grass .',
#  'a girl is a red shirt is playing a a skateboard . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is a riding a a blue . . . the blue . .',
#  'a in a in in in water of a red . . . a',
#  'a person in a blue in',
#  'a people are playing on a large . . white . . a . .',
#  'a man in on a camera . a man in a red .',
#  'a man in to a red and . a man . in a a crowd .',
#  'a brown dog is a a ball . . a of a field . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a boy girl in in a ball . a and . the snow .',
#  'a man in in to a ball .',
#  'a child boy in in a white and and a red and a . . a white shirt . a of a . . .',
#  'a man in a black shirt white and and is a white is . the . . .',
#  'a is a and white dog is in the . . . the .',
#  'a man in a man in playing a a man . the of a red . .',
#  'a man is jumping on on the blue of . a a . .',
#  'a dog and and white dog is on a field . .',
#  'a dogs are through a of . a field . . a . the snow .',
#  'a boy in in a shirt a and . a .',
#  'a men are playing in in a of running to a a water . .',
#  'a people are on the .',
#  'a dog dog is a grass . a beach . . . . the mouth .',
#  'a woman girl is running on the a',
#  'a man in jumping on a a . a a . .',
#  'a man people in a a camera . a grass .',
#  'a girl is a is in standing a a water .',
#  'a people sitting man in on a blue . a .',
#  'a in a and . a in . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog is a a ball .',
#  'a young are in playing in the air .',
#  'a girl boy in sitting a a red . . the red . .',
#  'a man in a red and white shirt and in standing a a . .',
#  'a man in a blue shirt and a on a red and on a red . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a black dog is on a black . a dog . a mouth . a dog dog in .',
#  'a man in a red and a a . a red . .',
#  'a man man is in in a a',
#  'a dogs white dog is through the a . a . . the .',
#  'a men are playing on the . . .',
#  'a people are in in a a air .',
#  'a man in a red in . a mouth .',
#  'a brown dog is in the water . . grass .',
#  'a man is a is on on on a beach . a ball . the air .',
#  'a are in a camera of a .',
#  'a girl girl in a red shirt white . is on a camera . a red .',
#  'a young boy girl is in the of a blue . . front . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a red and and and and a and in a',
#  'a dog dog dog running through a dog in the mouth .',
#  'a man in a blue and is running on a beach .',
#  'a man children are are a and . white in . a street . the water . .',
#  'a man in a . in large .',
#  'a in a and and a orange and of in a and . . a . . . the . . . .',
#  'a little boy girl in in a of . .',
#  'a man in a blue shirt is a red and and and .',
#  'a man in a blue shirt and a black in in a and . . . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a person is a blue shirt on in a a . the of a large .',
#  'a brown in in the snow .',
#  'a man dog is in the water . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man boy is a the air .',
#  'a white dog dog is running in a ball ball white . . .',
#  'a people in a a running in the water . the water .',
#  'a black dog dog is through the snow . .',
#  'a people in in orange . . . a city . .',
#  'a dogs are playing at in a large .',
#  'a man of in a large in',
#  'a man in a is on a red on a bike . a and .',
#  'a young girl in a white in a and is a a ball and a grass .',
#  'a people are in a in .',
#  'a man is on blue is .',
#  'a in on a a a building .',
#  'a people are a man are',
#  'a dog dog white dog is on a field . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dogs are on dog in a in in the field .',
#  'a man is jumping in a large . . a . a . a mouth .',
#  'a woman girl in a blue shirt and is a . blue . . .',
#  'a dogs are running on in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a red shirt a . . . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a men are in in other . the grass .',
#  'a man is a of of a rock . . a water . .',
#  'a people are a a red . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is a the water . a <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is a man is . a red . .',
#  'a man in on a water . a beach . a a . . a red .',
#  'people man of people a a and are and . a a one',
#  'a woman in a and is and a and and running a a red . .',
#  'a girl is sitting a red . . a . ball .',
#  'a dogs dogs are on the water of the beach .',
#  'a girls are a woman girl in on a red .',
#  'a man is a red is . jumping . a a a ball .',
#  'a people are in in a in standing on a man . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man boy and white dog is a a green . . . the field . a .',
#  'a man in in a a a snow . a . a . . .',
#  'a dogs dogs in in the . a in the . .',
#  'a dogs playing in dog in the . a . . .',
#  'a are a man of',
#  'a man in a blue shirt and white and is on a black dog .',
#  'a in a shirt and in a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a little boy in a red shirt is blue in a a and is in the red . .',
#  'a man boy in a red shirt is in a red . . a . . the air',
#  'a in in a of a . . . red . in a .',
#  'a black dog brown and dog is running a red . . . a a dog in .',
#  'a men on on on',
#  'a black dog is in a air . a grass of .',
#  'a man dog is a a in a on in . a grass .',
#  'a brown is running a beach . a dog . . .',
#  'a people are a in on the beach . the snow . a large . the snow .',
#  'a girl in a man in',
#  'a black dog is on ball . a ball . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young player in the and playing in water in the . a air .',
#  'a girls people are a man . . a ball . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is a red and is standing a red . a camera . .',
#  'a man is a in a red field . the of a .',
#  'a dog dog is in the air . a grassy . . a mouth .',
#  'a man is in a red shirt in a air .',
#  'a dogs are in other . the water . .',
#  'a children girls are in the pool . a water .',
#  'a man in a and sitting a',
#  'a man in a man in a of a red .',
#  'a boy is a a large . the field .',
#  'a dog dog is running on in a grass .',
#  'a dogs dogs are running in a ball dog in a white .',
#  'a man is in jumping on on a red . .',
#  'a are in a red and .',
#  'a children in a a street . a of a man . .',
#  'a man is is a is a white and is a bike in a air .',
#  'a dogs are in a air . . .',
#  'a man and on a a grassy . .',
#  'a man man on a red on a .',
#  'a black dog dog dog through the water . a field . .',
#  'a men are a man in is standing at a a camera . in in',
#  'a people are in the red . .',
#  'a black dog white dog is a black dog in a mouth . . a pool field . . . ball .',
#  'a dog dog is a in the snow .',
#  'a dogs dogs are in a orange . .',
#  'a boy in a man in a blue .',
#  'a man in a on man of a man in . a',
#  'a little in a on a a a . . a . a a beach . .',
#  'a in a red . . a .',
#  'a young are a man and in playing the water . a red in a water . .',
#  'a man is a is on of a beach .',
#  'a dog dog brown dog is running in a a the water .',
#  'a man is a on a in . blue . .',
#  'a people are in a field . a . .',
#  'a people in playing on in .',
#  'a boy girl in a boy playing a a and in a red . . a snow .',
#  'a man is a on in a red .',
#  'a black is and a red .',
#  'a boy wearing standing a and is a red .',
#  'a people are standing a . . a . .',
#  'a dog dog dog is on the grass . a grass . a field . .',
#  'a young in a blue shirt . is a',
#  'a in a is in a in a and and',
#  'a man is on a a snow .',
#  'a woman in a man is on in a',
#  'a dogs dog are running in the snow .',
#  'a man in in a a beach . a . a . dog .',
#  'a man is a blue ball a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a woman in a in a and . and .',
#  'a dog dog dog is running a a black field .',
#  'a people are in red . . . the .',
#  'a people are playing on a table . . mountain . .',
#  'a dog dog is through a ball . to a white .',
#  'a man boy in on a .',
#  'a black is running in the . the stick .',
#  'a dogs dogs are in a . . a ball . .',
#  'a brown dog dog a a white dog white brown . white dog white . . .',
#  'a girl boy in a blue is . a red . .',
#  'a people are a on the field .',
#  'a people are playing on a of . . a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a a and and a street . front black . .',
#  'a and is in a red . . the field . .',
#  'a man of people in a in a a street .',
#  'a boy in a and in on a a . . . a field . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man of a man of . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man of in a large',
#  'a men are in in in the grass . the . .',
#  'a man is on a red . . a . . . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a woman in wearing a red and in a red shirt is',
#  'a in in a blue . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a boy is in a a a ball .',
#  'a black of people is and a black . . .',
#  'a man in on a a a red of a bike . a . . a .',
#  'a man in standing a a in a bench .',
#  'a girl girl in to a man . . red . .',
#  'a children in the water .',
#  'a young is a red shirt and in a .',
#  'a man in a a',
#  'a man in a red shirt is a camera of a large . a . a . . a the grass . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dogs dogs are in the other in',
#  'a man is a shirt is on a . . the water .',
#  'a man girl in a is and to grass . .',
#  'a in in a . a . the skateboard . . a skateboard . .',
#  'a dog is a orange in . a grass .',
#  'a man player in in in a to a a ball . the of a man .',
#  'a men men in playing in a red . a . a .',
#  'a young girl a red shirt white shirt is in .',
#  'a black dog is in the . a .',
#  'a man is through a air .',
#  'a man girl in a red shirt is',
#  'a man is is in in a snow . a snow .',
#  'a girls girls girls are . a air . a . a',
#  'a men in in a man . .',
#  'a man is on man .',
#  'a dog dog is running the red of a .',
#  'a dog dog white dog is running a large ball in a mouth .',
#  'a man is jumping a a large . . . a beach . .',
#  'a man in a field ball white and and a black in a white in . a water .',
#  'a man girl in in in in to . .',
#  'a black dog white and is in a red .',
#  'a in on a a red . . a . .',
#  'a people are in a and a a standing a water . a blue . .',
#  'a people in in a air of a red . . .',
#  'a woman of people are in on a woman . a bench . .',
#  'a dogs dogs are on the air .',
#  'a man and in a a ball . a a .',
#  'a man is a red . .',
#  'a man is on a . .',
#  'a girl girl in in the a water . the tree . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a in a the snowy of . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young in boy in',
#  'a man in sitting a a man in in standing on the blue .',
#  'a young girl girl in a air . . standing on a large . . street . .',
#  'a brown dog is in to a dog dog . a a the field .',
#  'a man in a shirt a a red . a beach . a . .',
#  'a little girl in a red shirt white shirt . .',
#  'a dogs playing playing in in a dog and .',
#  'a dog is running on the beach . the . . and . . .',
#  'a little is a white shirt white shirt and a in .',
#  'a black dog white dog is running on a grassy .',
#  'a people people are on a red . a in . .',
#  'a man of in a in a . . .',
#  'a dogs are running in . .',
#  'a little a in in a blue . a . . . . a . . a grass . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a are in man . a street .',
#  'a man in a orange shirt is white and is walking in to a beach in a red shirt is a and is the air . to a grass .',
#  'a man man in in a a of a red . .',
#  'a dogs dogs white dog are in in a beach .',
#  'a dog dog is a in white . a <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog is in the water .',
#  'a people player are playing are',
#  'a black dog is running on a red .',
#  'a girl in a red shirt is in a water . a beach . a . . a air .',
#  'a girl in a a and and in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a people are a are on the of a . on the of a building .',
#  'a dog dog is running the water water .',
#  'a woman in a red and . a and in a red .',
#  'a girl in a is is on a water . the air . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is in a bike . a snow . the of a mountain . .',
#  'a boy boy boy a and is sitting a a beach .',
#  'a man is a . a a on red .',
#  'a man in in a of . .',
#  'a people people are a of a red . a a of a large .',
#  'a man girl is a red shirt and a and standing on a red in . .',
#  'two dogs are in a dogs are to the water .',
#  'a brown dog is a blue in in the mouth . . the air .',
#  'a man of people in in a black shirt .',
#  'a man in a red shirt and and and a of and with a red . . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is in a field',
#  'a dog dog dog dog in running in the orange . . . .',
#  'a young in a shirt is and in running on a . . . a and white .',
#  'a man in a orange and on . ball . . .',
#  'a man in a girl and',
#  'a girl in on a street . a crowd in in a in . .',
#  'a man player in playing a snow . a white and a and . a and white and and is',
#  'a people are a is on the blue . . .',
#  'a men are are a a in standing a .',
#  'a man in a blue in on a street . . man in a red girl is .',
#  'a in jumping on a on .',
#  'a brown dog dog in the snow .',
#  'a little boy girl in a red in on in a field . .',
#  'a man in a man in a a red with',
#  'a dog is running in in a black in',
#  'a man in a shirt and . standing a .',
#  'a dog dog in jumping a in a grass . a ball dog white dog in',
#  'a brown dog dog dog in running on the of a red . a . . the grass . a field . .',
#  'a people in a is in a in to a white . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a black dog is a and .',
#  'a man in a a woman in a red . a .',
#  'a man is standing in on',
#  'a are a are in a white .',
#  'a man man is a red shirt is a . . . a white . .',
#  'a children are playing in a in in a in white . . . a . . the . ball .',
#  'a man is on a in woman . a orange . .',
#  'a man wearing on a red . . . a ball .',
#  'a young boy in a blue in a mouth . a . a',
#  'a girl in a is a sitting on a black . .',
#  'a man black girl is in a beach . .',
#  'a man is playing a a air of a water . a',
#  'a man is a a woman shirt . a and is',
#  'a dog dog in in the mouth .',
#  'a young boy in on a red .',
#  'a man dog in in the snow . a black . . the air .',
#  'a man in a red shirt is on a rock . .',
#  'a young boy in a black shirt is standing in the red . .',
#  'a are in a water . a . . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a people in in on a beach of a rock . . .',
#  'a is a on a a <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young are playing in a in a',
#  'a man is in a shirt in a of a red . . a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dogs dogs are a dog . . a red . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a people in in a . . . a bench . the air .',
#  'a black dog is a and white dog in',
#  'a black dog is in the water .',
#  'a girl in a red .',
#  'a is in orange . . a beach . a . man .',
#  'a dogs are in the field . a white . . snow .',
#  'a woman in a shirt standing a a a large . a grass . . . .',
#  'a black dog is a a ball . . .',
#  'a young are in the pool .',
#  'a people are in in and <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog dog is a orange dog . running a a of .',
#  'a man in a a of . a man in a large .',
#  'a man in in red in a a in . . a bench .',
#  'a men are in on the red .',
#  'a little boy girl and in in standing on the water . a woman . the red .',
#  'a dog is on a beach . . ball .',
#  'a on a bike . . a ball .',
#  'a player wearing woman player in of . . the . . the man .',
#  'a man man is a on a ball . . . . .',
#  'a dog is on the water . .',
#  'a man in a man and in a man .',
#  'a man is standing a .',
#  'a man boy is on a a a red . a . .',
#  'a dog is on a mouth . .',
#  'a boy in a shirt is air . .',
#  'a man boy in a blue shirt and <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a little is a red is is a water . .',
#  'a brown dog white dog is in a dog is',
#  'a man dog white dog is jumping on a field . .',
#  'a people are a blue shirt . a',
#  'a young boy in in a a in in in a water .',
#  'a girl girl is playing in a water .',
#  'a man in a air shirt and at a and . a . . a street . . .',
#  'a men are in a skateboard . the of a large . . .',
#  'a men girls are in in the in . a <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a blue shirt is a on a field',
#  'a young wearing in a red .',
#  'a white dog is a in in running . the .',
#  'a people are a of a a in . a ball .',
#  'a people on on a a bike .',
#  'a boy in a is on in a a skateboard . .',
#  'a man in a man in . a red',
#  'a dog is a in the the . a beach . .',
#  'a white is a a field . . a . . a field . .',
#  'a people are a shirt and white and in in . a . .',
#  'a young are in a in . a a red . the air . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young in a orange in',
#  'a man is riding on a red . . . .',
#  'a man in a in on a . . . a man .',
#  'a man is standing a of of',
#  'a brown dog dog is in',
#  'a young boy in in a blue shirt . . a field . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog dog dog in running in the beach . .',
#  'a man in a a red .',
#  'a in a a the red . . a ball . . a air .',
#  'a boy girl in a shirt in in a grass .',
#  'a black is in a beach .',
#  'a black is a a a ball in the field . .',
#  'a people are in a on the red . . the beach . of a .',
#  'a people are in a beach . . a red .',
#  'a dog dog is running on a .',
#  'a man in a orange and is in to . the red . .',
#  'a dog dog white dog is running through the field . . . . field dog .',
#  'a man of standing a on on a . beach . a . .',
#  'a man in on a man . a red . a . woman .',
#  'a man children in playing on in a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a blue shirt is in a yellow . to a large .',
#  'a young in a red shirt white and is a red and . a .',
#  'a man in sitting a man on a green . the red . .',
#  'a girl in a red and is in a water .',
#  'a children are on a blue . the field .',
#  'a boy boy is a blue shirt and running on . a .',
#  'a man of people are a of .',
#  'a in running a . a white . . . a . .',
#  'a girl in a a blue . .',
#  'a men are in a red . . .',
#  'a dogs and are running through a man field .',
#  'a man in a a in to . a woman in a blue . . . a street .',
#  'a dog dog white dog is through the grass . a in water . .',
#  'a dog is a a air . a red .',
#  'a dog is in a a a . a field . . .',
#  'a man in in a bike .',
#  'a man is a in standing a blue of . . a white ball . the water .',
#  'a man man and . a white .',
#  'a man in standing a rock . . a a black . . <pad> . rock .',
#  'a dogs are a large . . a mouth . a ball .',
#  'a boy is standing in .',
#  'a man man in a man in on a . a bike .',
#  'a people are sitting on a beach of',
#  'a dog is on a air . a a mouth and of <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man boy is a red shirt a shirt . a orange . . . a air .',
#  'a dog dog dog is a dog . a mouth . . the .',
#  'a woman is a red with a blue shirt is <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a girl in a black shirt and on a red . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is a bike in . . . a on . trick .',
#  'a boy boy in a air and . . a and . . a on a rock . .',
#  'a white is a in a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a boy in a red and in running on a beach',
#  'a people are on in white .',
#  'a brown in running a blue in the snow . the in water . a a',
#  'a little is a red in a . a of a red . a dog ball a water .',
#  'a in a in in the beach .',
#  'a man man is sitting a blue on on',
#  'a man man of a are in the blue',
#  'a dog is on a ball . .',
#  'a girl boy in wearing in a .',
#  'a are in orange . . . . a . . a .',
#  'a people are in in a air . .',
#  'a woman in a red shirt shirt is a red in . a rock . the water .',
#  'a boy is a red and and a a in the field .',
#  'a man boy in a a head and and a in are on . the blue . .',
#  'a in a a and .',
#  'a people are on a of a grassy . . . a .',
#  'a dog is a dog in the . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a little wearing a a red and . .',
#  'a man in on a street .',
#  'a men are in one are a orange . . white is the blue shirt . and . a grass .',
#  'a man is a a air . .',
#  'a is standing woman girl in a red shirt and white white girl is a red shirt . in a blue . a .',
#  'a man boy in a red shirt is on a street . a ball . a grassy . .',
#  'a man is a snow . a beach . a . a . .',
#  'a in a shirt and a a and a and . . a a . a to . a in the dog .',
#  'a dog is in a water .',
#  'a girl in a in playing a on',
#  'a dog dog and a mouth . a in . the field . .',
#  'a man in a of standing a a red . a small .',
#  'a white dog dog in in the .',
#  'a man in a a camera . a man . . to a .',
#  'a young girl is on a blue . . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog is in in a a ball in',
#  'a of people are in a of a orange . . .',
#  'a child girl is a white shirt is a is standing a a rock . . .',
#  'a man player in a and a a field .',
#  'a in a in a the . the the field .',
#  'a man boy a a a beach . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'two dogs are in a other in a . . .',
#  'a young in a shirt a .',
#  'a woman in a red shirt is in a men . . . . .',
#  'a in a red in a running a a ball .',
#  'a boy man is in in a large of a . .',
#  'a men are are in in the red .',
#  'a man in a orange shirt is sitting a a a red .',
#  'a people are a in and a of',
#  'a boy is a black and and a and a . a of a .',
#  'a man in on a orange . .',
#  'a dog dog running in a dog ball .',
#  'a man in standing a a . a of .',
#  'a people are in a in a and . a . . . . . a camera .',
#  'a people are are in crowd . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog dog is running in in the field .',
#  'a man in a red shirt and a a is a man . and in a of a red . . . . .',
#  'a man is a and standing on a red .',
#  'a man in in a woman woman sitting in a camera . the of white . a man .',
#  'a is a white in a black of the grass .',
#  'a dog dog dog in the .',
#  'a man in a man a air .',
#  'a dog in the grass . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a child in in a red . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young girl in a blue is a shirt on . a rock . .',
#  'a man in in a red shirt and a is',
#  'two dog dog in to a dog dog dog white dog running a dog dog dog is . .',
#  'two girls men are are in a grass .',
#  'a dog dog is a dog in the mouth .',
#  'a girl in a a a',
#  'a man is is a a . a . water .',
#  'a man is a large of in . a field . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man wearing a sitting in a . street . a . . . a snow . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man boy is playing on a a water . . .',
#  'a dog dog in running a dog in a . . . a in running in a . .',
#  'a man in a a air . a . . .',
#  'a man is on in running on a white .',
#  'a are on on on a white on in',
#  'a people people a a in girl white is orange . a in . with',
#  'a man in in a the other . the snow . a red .',
#  'a boy in standing on rock in . in on .',
#  'a woman in wearing a man . a . a woman in sitting a a woman . a .',
#  'a man in a woman in a red shirt a sitting a bike . . a of . a street .',
#  'a dog dog is in a . a beach . .',
#  'a man in a and and a white . a mouth . a . a red .',
#  'a dogs dogs are a grass .',
#  'a woman in in on a water . a air . . . .',
#  'a children in a orange and . and dogs people street in a . .',
#  'a dog is running a white in the ball . a .',
#  'a man boy is in a blue shirt is and a and is a blue . a . . . . a .',
#  'a white is through a grassy . . . field . .',
#  'a man in a shirt is a a blue . .',
#  'a dog is running a in the red . a . a . on a',
#  'a people are in front in',
#  'a man in a orange . . .',
#  'a man in on a air . a a red . a mouth .',
#  'a in white dog a in a ball . .',
#  'a person in in a a snow . . . .',
#  'a in in a red . a field .',
#  'a man is on a street of a street . a . a street . a field .',
#  'a man in in a of water . .',
#  'a boy in in a orange shirt and jumping a red . . a . . a . a ball .',
#  'a man in in a of a white . a .',
#  'a people are on a . a red . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man man man is a red . .',
#  'a young girl in on a red . . a red . a',
#  'a girls are in a are are . . a red .',
#  'a man in a in the field . a . . .',
#  'a young in a blue on . a ball .',
#  'a young girl playing a',
#  'a man man man is sitting on a rock . a . . a red . .',
#  'a young in a air . a mouth in .',
#  'a man in running a blue in .',
#  'a dog in a black and in a in in a brown dog is',
#  'a woman in in a blue shirt white and and a and and standing on a skateboard .',
#  'a man in a orange shirt is . a .',
#  'a dogs are running through a field .',
#  'a young in in a street . a boy in .',
#  'a man in sitting a a red in a .',
#  'a boy in a a the . a one a .',
#  'a brown dog dog brown dog dog dog dog and a white is <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a girl girl is in a and and and on . a .',
#  'a man is a red on a a bike . . a .',
#  'a children are a in a in a field .',
#  'a man in on a orange . . a . .',
#  'a men are on a red . . a large in a a',
#  'a man boy is a large man . a . a large . . . .',
#  'a people in in a snow . a in .',
#  'a dog is a the . . a <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog dog is in a . the field .',
#  'a man is jumping a a the air .',
#  'a man in a blue shirt and in .',
#  'a boy girl in a to . in .',
#  'a man is a and on a .',
#  'a man of a bike . a . .',
#  'a boy boy in a and a . . the field . .',
#  'a girls are in in a grass .',
#  'a young in a a . a rock . .',
#  'a young in a and . .',
#  'a man man is a blue .',
#  'a in a a blue . the field . .',
#  'a man is a red in is . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a on a . the water .',
#  'a is in to red . . a . . the of a .',
#  'a people are are one in a red . and a camera . the shirt and . a man . .',
#  'a man in a man in playing a a red . a field .',
#  'a dogs dog are running in the field .',
#  'a boy in a is on a a . a white . . . . blue . white .',
#  'a dogs dogs dog are a dog in . a a . a field dog . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man player in in in . the grass . a man in .',
#  'a man in a and and running on a red . a . .',
#  'a dog of brown dog are running in the black . a dog .',
#  'a man are people in a are',
#  'a dog dog is black white dog white dog is in a ball . the snow .',
#  'a children are are a grass .',
#  'a white dog dog is in a .',
#  'a people are in a the . . a . . . the picture . . . . the water .',
#  'a people are a in and a in in on a',
#  'a man is riding on a bike shirt .',
#  'a dog in running a dog in the snow . a a dog is . a',
#  'a man is a man shirt is sitting a red .',
#  'a children people in playing on bike and . . . a bike . .',
#  'a girl in a blue shirt shirt and a red shirt a . a red .',
#  'a is playing are are a . a',
#  'a are of a air . .',
#  'a man in playing in in',
#  'a woman man in in . people in',
#  'a in in the water . a beach . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a people are on the . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a people in a blue of a and . . . .',
#  'a girl girl boy in in the white shirt . a . . the field . . a . . the .',
#  'a man is a white of a red . .',
#  'a people are a bike .',
#  'a man is jumping a a rock . . . a grassy .',
#  'a man in a is a and in red . a man . .',
#  'a dogs are a black . in the',
#  'a white white dog is running in the water . . a grass . a black . a . . . . a . dog dog . in in',
#  'a young boy is a in in',
#  'a man of people in a shirt in a on a street .',
#  'a man in on a orange . . . a . . .',
#  'a man boy in a water . . a . .',
#  'a man in a black and a man is and on a red . . white .',
#  'two dog dog is in a dog in a dogs . in a .',
#  'a man in a red shirt is standing on a . . the air .',
#  'a man of a in on blue of on .',
#  'a man are are in a white . .',
#  'a black dog is in ball and in running in the water . a black . the mouth .',
#  'a man of people are in a orange . . a . a . .',
#  'a in a in a of a . . . the . .',
#  'a young are in in woman and .',
#  'a man in a red shirt is a red . the air .',
#  'a man in a and riding in snowy . . .',
#  'a dog dog is a dog dog is a white and is in . . the field . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog dog is a white dog in the mouth . running on a . the field . .',
#  'a black dog is a orange in a air .',
#  'a dogs are white dogs are playing in the water . a . a beach .',
#  'a man boy is sitting a blue . . a background .',
#  'a man is on a in a water . a .',
#  'a dogs are in the a . the air .',
#  'a dog is through a',
#  'a dogs are in a large . the field . .',
#  'a man in a standing on a red in . a . a . .',
#  'a man in in in in in in the field . . .',
#  'a boy in a on <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog dog white dog is in a a water . white black and . . .',
#  'a in in camera with a woman girl is a .',
#  'a man is running a black in a a red . the of a . .',
#  'a man boy in standing on a a rock of a of .',
#  'a man is a red . . . . a ball . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is jumping on the water . a .',
#  'a man in a red shirt and a is a a a in a shirt',
#  'a dog in on a ball . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a man of . a a .',
#  'a man is a red is jumping on a large . . sitting a .',
#  'a man is jumping on a trick . to a a . a ball .',
#  'a people are a',
#  'a man in a red shirt and a standing on to a a a',
#  'a woman in in a and a standing on a water .',
#  'a black dog white dog in a ball and .',
#  'a man wearing standing in a a of a man .',
#  'a woman of people in playing on a white . .',
#  'a man in a shirt in standing a air water .',
#  'a man in a red shirt and a and . and a man in in standing on the of a white . .',
#  'a in a shirt is a is a a red . .',
#  'a dogs dogs are in a grass . .',
#  'a man is a white dog . running a grass of a black . a water .',
#  'a man and with on other . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is a air is . a mouth .',
#  'a dogs and in the snow .',
#  'a people are playing in on the field .',
#  'a children are in in on the red .',
#  'a man girl in in a of a black . a . a . .',
#  'a man in playing a man of . a . . jumping to a water .',
#  'a dog in running on a red with in running on a blue . white dog . . .',
#  'a little in a white shirt is and standing a red . . a mouth .',
#  'a brown of dogs are in a ball . a . . a .',
#  'a man in a man woman a and',
#  'a man of people people people in a are . . a and . a .',
#  'a boy in a and is a man in a a . .',
#  'a man girl in a in standing in a orange',
#  'a man is a red on on a beach of a large .',
#  'a little boy in a on on . a red . .',
#  'a people a are in a in in a the large of . . a black dog . . the',
#  'a man wearing wearing a a red in a . a red . . .',
#  'a woman is a shirt and and a woman and and on a red of .',
#  'a man dog white dog is a snow . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a man in a water . . . .',
#  'a brown dog is to a white dog is running a white . .',
#  'a man in a blue is with . .',
#  'a black dog is running a black dog is a grass . .',
#  'a people are a woman in in a camera .',
#  'a dog dog and a . a . . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog is through the grass .',
#  'a man is a bike bike . jumping the . . mountain . a street . .',
#  'a man in in . a a ball .',
#  'a dogs are a dog and a . a <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog is on a field . . . .',
#  'a black dog is a black dog white dog is running on the . .',
#  'a man is standing a rock in',
#  'a man player in a red and . jumping on a red .',
#  'a man in a red shirt in on a blue .',
#  'a people are in on a in at a man .',
#  'a man in on air of a white',
#  'a dog dog dog is a a ball dog . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is on a blue shirt . a',
#  'a man man is a blue shirt is is rock of . a <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a woman girl in a and a blue shirt and <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is on on a . a on on skateboard of .',
#  'a man in a a in standing a and a and and .',
#  'a man boy in a red in a a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young boy in a blue shirt a a . a . . . ball in a red . . a',
#  'a people are playing in the water . a beach .',
#  'a girl in a a red . a on a grass .',
#  'a in a on the air . a red . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a girl is on a man . a ball girl in a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a girl girl in a in in in a large . .',
#  'a people are a in in on blue in a red .',
#  'a girls are playing the in a red . .',
#  'a man of of street in a man . . a',
#  'a dogs are running in the grass .',
#  'a men in are a and and a a . a',
#  'a children girl are playing on a . . .',
#  'a man of people man are on a white . .',
#  'a man are in the snow . a in',
#  'a people in on a field . . . the . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog dog is a white dog is a black . the mouth . . .',
#  'a group in a a red in a in . a rock . . .',
#  'a man is a and is a air and is in a head . a head .',
#  'a young in on standing a a . . blue . the blue . .',
#  'a woman in a and in in . a man .',
#  'a white is a red field .',
#  'a man man is a and a mouth and a a . a',
#  'a people people are playing in the air . a . the water . a the snow . . . .',
#  'a man in in a of a orange . the water .',
#  'a young in a a water . a water . a ball . . a . .',
#  'a people in a in a white in in a .',
#  'a man in a red shirt in a white in a orange and is a a and . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man of a a people people in . . water . .',
#  'a man is in a bike on',
#  'a young in in in the water . a pool . .',
#  'a man is on a skateboard . the .',
#  'a little in a of a . . . . . camera . a .',
#  'a black is on the grass .',
#  'a dogs dogs running in a dogs in the beach .',
#  'a man man man a is . . a',
#  'a man is is and is white shirt in a dog . the water .',
#  'a people girls girls in in a white . a blue .',
#  'a man in a man in a red . .',
#  'a man is a man and on a red . . a in a . on',
#  'a people boy are in a and a red . . . a red . a air .',
#  'a are playing in . . .',
#  'a girl girl in wearing on a snow . . a grass . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man of people are a beach . a orange . .',
#  'a man is on a air .',
#  'a man in a dog a in on a large . the field .',
#  'a dogs are in the water .',
#  'a boy in a red ball a ball .',
#  'a man boy is a the air . a mouth . .',
#  'a woman in on a a air .',
#  'a man in a black and a standing on a beach . a . .',
#  'a people are in a a . a . and a and a air .',
#  'a man is riding on a',
#  'a man in a red shirt and a is . . a . .',
#  'a in on a in . a . . a . a .',
#  'a man boy is on a street . a .',
#  'a man is a water of front of a a of .',
#  'a white dog dog is in a a ball . .',
#  'a dog dog is in the grass . a red . .',
#  'a dog dog white dog is in a grass . a field . the mouth . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog in a black shirt and and a is a orange .',
#  'a man in a in a woman of a woman in a water .',
#  'two man in a in the water in a of in',
#  'a young in a a and red and in a brown in a and a and is a a',
#  'a in a and . and . . . a . . . . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a black dog is a . in a the of a water .',
#  'a little girl in a red in .',
#  'a man in jumping a green and white dog is a field in . . the . . .',
#  'a white is a white white and . . .',
#  'a man is a orange . a air . front red .',
#  'a dog is a a a . a a .',
#  'a dog dog dog is through the black of a .',
#  'a young in a red shirt is and and . blue .',
#  'a man on a a .',
#  'a man is a blue is jumping on a of a in a .',
#  'a man in a blue in standing a grass . a blue . . .',
#  'a man dog white dog is standing in a field . a . . . . .',
#  'a man is a a . .',
#  'a man man and in a man of a water . a street boy in . water .',
#  'a dogs are in a black dog .',
#  'a man is on a beach of a red . .',
#  'a people are on a orange . .',
#  'a man in a red and . a red shirt . a',
#  'a are a a a .',
#  'a man in a woman . a',
#  'a are a black of white a a at a',
#  'a in a shirt is a on a',
#  'a man girl is a shirt and a blue . .',
#  'a men are a a street .',
#  'a girl girls is a in in a white . a . a . .',
#  'two dog is a running a the . running in .',
#  'a in in are in in',
#  'a man is in in a on a bicycle on . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man is in playing a a in a in',
#  'a man of people are playing a street . a red .',
#  'a man in a a on . a on . . . .',
#  'a dog is running on a a .',
#  'a boy is in in and a in a . a on a ball .',
#  'a man woman with in a red shirt and standing a red . a in to a man . a',
#  'a man in in in',
#  'a in a in in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a in on in',
#  'a white in a and standing a red dog in a small dog is in a a of a .',
#  'a man wearing a red is a is a of a white shirt .',
#  'a in a and on a red shirt . .',
#  'a young girl in a and a on . .',
#  'a man in a and white white and a and running a dog . .',
#  'a man of people are in street of a street . a . . a .',
#  'a in a man in',
#  'a white in a white in . a a . a dog and . the ball . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in running on a a water in',
#  'a woman in in a a . . . .',
#  'a woman is a man is a in a red . . a of a orange . . .',
#  'a men are a and playing in a camera of a man of a .',
#  'a man is a a large of .',
#  'a people on on on a bike . . a field .',
#  'a man is a red in a mountain . the water .',
#  'a black black dog is a a a',
#  'a are in ball . a camera . a . holding the background .',
#  'a dog dog is running through the field . .',
#  'a man is a a man in',
#  'a man is a black of is sitting on a snow . a field .',
#  'a and in the air . .',
#  'a man in a red . a table . .',
#  'a man in a bike on a a street .',
#  'a dog white dog is a a a water .',
#  'a man is on a yellow of a in . a . . a .',
#  'a dog in the water .',
#  'two young is in in running in orange . in',
#  'a man boy in in a red . . . . . . .',
#  'a man is of on orange . . a .',
#  'a man in a is standing on a . .',
#  'a brown dog is a grass dog is a a a .',
#  'a people are a white .',
#  'a men in a a a .',
#  'a man in the red in jumping in a water water .',
#  'a man in a man and is a a in a . . standing . a grassy .',
#  'a black dog dog dog is in a the ball .',
#  'a man is standing a a mountain . .',
#  'a man wearing a a red . a a orange . . .',
#  'a girl boy in sitting in a in . a',
#  'a man is is a orange . .',
#  'a man is a air shirt is walking on a',
#  'a man in a red shirt . a . . a a . a . .',
#  'a man in on a a bike . a people are . a . .',
#  'a black dog white dog is in the snow . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man man a red shirt shirt a and white and and and .',
#  'a man a in a boy in a camera in a shirt . playing . .',
#  'a is a red . a bike . . the grass .',
#  'a are a grass . a man of the water .',
#  'a brown dog dog is running on a water . a field . white dog .',
#  'a girl girl in a blue shirt is . a red .',
#  'a dog dog is through the air .',
#  'a children are in are a in grass . a dog . . ball .',
#  'a boy boy in a red shirt and standing on a to a of .',
#  'a man is jumping on a red .',
#  'a man in a is a a red . .',
#  'a dog dog is running in a .',
#  'a people in a man in a man .',
#  'a black is a in and a a water and .',
#  'a are playing a in a orange . a water . a . a of . .',
#  'a dog dog dog a orange a a mouth .',
#  'a man girl in a and a red of on . a street . .',
#  'a young in in in .',
#  'a man is in a dirt . . a ball and . a beach . . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a girls in in a air .',
#  'a white in a a grass .',
#  'a dog dog is in the grass .',
#  'a man of people are in a of a mountain . . the .',
#  'a little boy in a blue shirt and on a red . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a brown dog is a red dog white dog . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man of a are in in',
#  'a in playing a on a . . . .',
#  'a dog is a shirt white is in a is on running a . a large . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a woman girl in a shirt on a a a a . . the air .',
#  'a woman in wearing a red shirt and is a man and in',
#  'a dog and is on a grass . a mouth . .',
#  'a man of in a a . a',
#  'a dogs are in the beach .',
#  'a brown dog is a white is and in a mouth . running in the blue . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a are a man .',
#  'a man wearing a shirt white shirt jumping in blue . . . . . .',
#  'a little in a red shirt is standing in the . .',
#  'a woman man in a red shirt and a a orange . .',
#  'a men are a shirt and in and a red . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man girl in a a red boy and in . a blue . . a . . the snow .',
#  'a dogs are through a grass of .',
#  'a man in a red shirt and a and in on a the red .',
#  'a children are in a black of a and . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in sitting a man shirt . a blue . .',
#  'a dog dog in running on a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a a in a a and and a a a . .',
#  'a people in a in on the ball . .',
#  'a man in on a a white . . . a . . . .',
#  'a white dog is running in a white field .',
#  'a man are playing a . . the .',
#  'a man in a on a shirt is on a bike . .',
#  'a man in a in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man of people are in a camera . the of a . . white .',
#  'a people in playing a in a in in in a the',
#  'a girls are in orange . . .',
#  'a man in a blue in on . mouth . a . . a . .',
#  'a people are playing a a street . a red . .',
#  'a man is is on a blue and white is a on on a bike .',
#  'a man boy in a in a and and . .',
#  'a in a red in . a red . a . . the . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  ...]

# %%
true_captions
# Out:
# ['a toddler is sitting down .',
#  'man carrying a tool box on a sidewalk',
#  'two men are sitting on a bench looking at a water fountain',
#  'two people watch tv from over a white ledge .',
#  'a young woman crosses a bridge through a field of tall grass .',
#  'two youn boys lay in a dog house with their dog .',
#  'a dog in the snow carrying a tree limb in its mouth .',
#  'a girl sits and laughs while in a kiddie pool .',
#  'a boy wearing black swimming trunks is standing in a fountain .',
#  'the brown dog pulls a skier across snow-covered ground .',
#  'the owner tries to hand a deflated ball to his dog .',
#  'three climbers on rocks near waterfall .',
#  'a black dog carries a white toy in his mouth and walks on the snowy field .',
#  'four children .',
#  'a man in jeans is using a yard work tool just above some pavement steps .',
#  'a child in a gray t-shirt is bouncing a basketball on a basketball court .',
#  'a dog races while wearing number 6 .',
#  'a woman holding a ball chases a small boy running in the grass .',
#  'a brown and white dog with big brown eyes with a dishtowel in his mouth on a hardwood floor .',
#  'a skateboarder ollies .',
#  'woman with two medals around her neck <unk> holding up seven fingers .',
#  'a little girl holding a frilly white dress out for the other little girl to examine .',
#  'members of two soccer teams struggle on the field to get the ball .',
#  'an elderly woman sits in a chair and wear a winter hat and coat .',
#  'dog standing in grassy sand dune .',
#  'a black guy in a apron grilling cornstalks .',
#  'a brown dog runs on brown grass .',
#  'two children wearing orange walk across a long pier .',
#  'a large brown dog is digging in the sand .',
#  'three dogs race towards the viewer over a lawn .',
#  'two dogs romp through a meadow of high grasses',
#  'a man plays a bagpipe while another checks on the instrument .',
#  'the black dog is running through the water on the beach .',
#  'people are riding in a boat with oars .',
#  'a man rides large waves on a wind sail .',
#  'a black dog runs across the dirt road .',
#  'a dog stands shoulder deep in muddy water .',
#  'a woman in a string bathing suit with a man on a boardwalk on a foggy day .',
#  'two soccer teams are playing <unk> one is in white the other in red .',
#  'a woman wearing an orange jacket sitting in a canoe on a lake with a dog behind her',
#  'a girl laying on the tree with a boy kneeling before her .',
#  'adults and children stand outside of open barn .',
#  'a boy holding an oar walk through the ocean .',
#  'a white car racing in the dirt and water',
#  'three children jumping into a pool with a palm tree in the middle .',
#  'a man reads quietly alone in room .',
#  'the young man dives on the field during a sporting event .',
#  'a brown and black dog approaching a red ball .',
#  'three boys are struggling with one another and reaching for bag of litter .',
#  'girls cartwheeling inside .',
#  'a child flying a kite .',
#  'black dog jumps through snowy field .',
#  'four people walk on a bridge over a body of water .',
#  'two girls hugging .',
#  'little kids play in the water while their friend poses on top of their raft .',
#  'a large van drives down a counry road in the fall .',
#  'the head coach is walking out on the field .',
#  'a boy wearing a flowered shirt raises his arm and jumps .',
#  'a group of people are in the water .',
#  'three teens watching a basketball in the air .',
#  'a young boy jumping into a pool .',
#  'boy jumping off skateboard as it goes down the stairs .',
#  'a man holds a fish in both hands .',
#  'two asian girls dressed in black pose for a picture in front of dry trees .',
#  'a man works on his garden .',
#  'man and dog standing on the beach .',
#  'two long haired dogs racing down a forest path .',
#  'a soccer player in a white shirt kicked a goal .',
#  'a group of older people are sitting outside under their marine-life-themed umbrella .',
#  'a woman in a green shirt and blue hat is playing tennis .',
#  'a black puppy standing inside beside an orange .',
#  'the person in the red and black uniform has a ball above her head .',
#  'two brown and black dogs run through the dry grass .',
#  'two women <unk> one looking down <unk> the other drinking .',
#  'the yellow dog is carrying a stick by water .',
#  'a young child is running through a large puddle at a beach surrounded by trees .',
#  'a man on an escalator carrying a red and white cup looking up .',
#  'a man in a red shirt is jumping from one rock to another larger rocker with two male spotters below him .',
#  'a person riding a horse with a mountain range in the far background .',
#  'three young people pose by a snowman in a red tie .',
#  'two little girls <unk> wearing pink hanging on a tube .',
#  'two men walking past a graffited wall scene of a red classic car',
#  'four people are in silhouette whilst watching the sunset .',
#  'a dog chases a white animal on a green lawn .',
#  'a person is wading through a river near an eroded embankment .',
#  'woman on grass <unk> <unk> small dog as another dog jumps up .',
#  'a skier rapidly descending a steep snow covered hill .',
#  'a person wearing a white shirt and blue shorts with cables attached to him .',
#  'a group of people sitting at a sporting event .',
#  'two men taking a picture together with the phone of one of the men',
#  'a young boy practices his bat swing while in the stands with blue seats .',
#  'a woman holds a baby while a man looks at it as another man holding a child watches .',
#  'two kids playing on the beach <unk> close to the water',
#  'a black dog is running along the beach beside a brown dog in midair catching a stick in its mouth .',
#  'a man in a full wetsuit surfs a crashing wave .',
#  'a surfer vertical in a wave with another approaching him',
#  'the brown dog is standing on the beach as the waves lap up around its feet .',
#  'a man in a white outfit on a bench',
#  'three women sit on the subway ; one talks on the phone while the others read .',
#  'a brown dog digs in the sand happily .',
#  'the man is standing in the river next to smoking grass .',
#  'a swimmer is doing the backstroke in the swimming pool .',
#  'two elderly females sitting on a white bench amongst trees .',
#  'a boy plays with a water tube .',
#  'a child in red sits in the snow .',
#  'a man windsurfs in the ocean .',
#  'the bike rider is wearing a silver helmet and red shirt .',
#  'a black dog leaps through the snow near a fence .',
#  'a motocross bike is jumping through the air between two lines of red tape .',
#  'several people in a park walking on a low wooden boardwalk .',
#  'a baby wearing green holds onto plants and puts them in its mouth .',
#  'a man in a knit cap stands next to a brick wall .',
#  'a black insect approaches a flower .',
#  'three uno cards in reds and yellows in the foreground <unk> with a young boy holding <unk> cards in the background .',
#  'a little girl is smiling <unk> while running outside .',
#  'a tan dog climbing over a bare tree trunk with a man standing in the background',
#  'a man jumps off a hill .',
#  'dog yawns',
#  'a man wearing a pirate hat and eyepatch smiles at the camera .',
#  'a close-up of a man shooting a handgun into the woods .',
#  'three black dogs play in the glass .',
#  'little boy in yellow shirt is climbing out of a plastic playground tunnel .',
#  'an asian girl is smiling whilst standing in font of some green bushes .',
#  'two black dogs and one brown dog in tall grass .',
#  'a man in a hardhat stands beside a ladder .',
#  'a lean dog runs through green grass .',
#  'people mill about a large are with a round desk .',
#  'a young boy is twisting a sparkler around in the air .',
#  'three people standing near a door <unk> with silly string cans .',
#  'two dogs running through tall grass .',
#  'two people are on top of a cannon .',
#  'the skateboard is falling away from the skateboarder as he attempt a jump .',
#  'goal attempt during a soccer game being played on green grass .',
#  'a boy in a green t-shirt is riding on a segway',
#  'a mountain biker is riding along a heavy dirt trail in a wooded area .',
#  'man helps another person reach the top of a rock they are climbing .',
#  'a man climbing a cliff .',
#  'two bums are sitting on a sidewalk outside a peace mission in portland oregon .',
#  'a man looking at the camera with another man wearing a mask .',
#  'a man next to a plastic crate and a bicycle <unk> writes on a board .',
#  'a small dog laying on a stuffed animal in front of a tv',
#  'a little girl walks on a boardwalk with blue domes in the background .',
#  'a man stands next to a car .',
#  'a small boy dressed in a black sweatshirt with a logo on it <unk> holds a red bat in front of blue stadium seats .',
#  'a kangaroo wearing a yellow and black striped vest with the number eight on it is hopping .',
#  'dog with black and tan face standing in water looking up at camera .',
#  'a man and a woman are posing for a photograph in front of a yellow flower-bed .',
#  'a kayaker is battling waves in a purple boat while wearing rain gear .',
#  'brown <unk> black and white dog standing on a sandy slope .',
#  'two dogs run towards each other on a rocky area with water in the background .',
#  'young boy dressed in green holds baby goat in arms .',
#  'two men are playing basketball and one is trying to block the others shot .',
#  'football players playing in mud .',
#  'a white dog in the snow carries a plastic mountain dew bottle in its mouth .',
#  'a young boy is playing in leaves .',
#  'a man is sitting in room made up of wood panelling .',
#  'the football player runs with the ball across the field .',
#  'a girl in striped swimsuit is jumping into the ocean .',
#  'there is a man sitting in a restaurant at night .',
#  'guy in santa suit wearing ninja mask and horns',
#  'a dog jumps over a barrier .',
#  'three shirtless boys are playing in the water .',
#  'a young girl is sliding down a snow slope in a red sled .',
#  'a snowboarder wearing a black and white striped jacket is kicking up some snow .',
#  'a person wearing a white hooded sweatshirt covered with a blanket sitting on a bench reading',
#  'one black dog running with a ball and small tire in his mouth while another black dog follows .',
#  'a person wearing a helmet begins to fall from a silver scooter .',
#  'a bald <unk> shirtless man rock climbing .',
#  'brown and white dog runs towards camera <unk> casting long shadow on dirt .',
#  'two children are sitting in some tree branches .',
#  'some children turned backwards while in the audience .',
#  'a man raises a campaign sign over his head .',
#  'a beige dog runs through the shrubbery toward the camera .',
#  'a person in hiking gear is standing on a hill with a mountain in the background .',
#  'people look out the window at mountains .',
#  'a small girl wearing a white and multi-print dress sitting at the bottom of a slide .',
#  'a young blond girl standing in front of a large fenced in fountain',
#  'a woman in a pink striped shirt <unk> with her hand up .',
#  'a german shepherd is running with a stick in its mouth .',
#  'a boy wearing a white hat is running on the beach .',
#  'the two football players in white jerseys and purple pants tackle the player in the red jersey .',
#  'a man on rollerblades grinds a wall .',
#  'girl in black pants and an orange top jumping with one leg outstreached and foot pointed other in background dressed the same .',
#  'a young asian girl stands between two tree trunks .',
#  'a man in a yellow shirt wears a gold <unk> <unk> mask .',
#  'a man in a blue jacket lifts a child dressed in red out boat crowded with people',
#  'a man in a green hat standing on a slope in front of a mountain .',
#  'the dogs play on the snow .',
#  'a tan dog swimming in some water',
#  'a young man parasailing in the ocean .',
#  'a small white dog is jumping over a green and red obstacle bar .',
#  'two girls in swimsuits are playing in the water near the seashore .',
#  'a small black dog runs through the white snow .',
#  'guys gathered outside an ice cream store on a sunny day .',
#  'two dogs are looking up at a person .',
#  'an irish dancer performs a solo .',
#  'a man wearing no shirt does a trick on his red and black bicycle .',
#  'a little girl with a bow in her hair <unk> doing a <unk> on the grass .',
#  'three kids play with silly string .',
#  'a motorcyclist navigates a forest trail .',
#  'man sitting with headphones at a laptop .',
#  'four people and the sun .',
#  'a black and brown dog running in a field',
#  'two dogs <unk> one lying down <unk> play in a yard .',
#  'the matador is struck by a charging bull as he stabs it with his swords .',
#  'a young girl in a pink room tries to play a black electric guitar .',
#  'two dogs are playing together',
#  'a woman in a salon gets her hair colored and permed',
#  'two basketball players oppose each other at the net .',
#  'a climber approaches the top of a cliff high above the surrounding terrain .',
#  'three boys climb on a slide',
#  'a man parasails in the waves <unk>',
#  'a boy does a skateboard jump at a skateboard park .',
#  'a man stands at the peak of a mountain and has his hand on a monument .',
#  'a street market filled with white tents <unk> pedestrians <unk> and <unk> .',
#  'a girl with bright red hair and black clothes is posing on a tree trunk .',
#  'the girl is at a petting zoo and feeding a camel .',
#  'two black dogs splash through the waves on a beach .',
#  'two parents and a young girl blow up a raft .',
#  'a skier in a ski suit is skiing downhill <unk> near a fence .',
#  'two men dressed jackets and hats are standing on a terrace',
#  'a small brown and white dog lines on a red area rug in a patch of sunlight .',
#  'a woman searching for cans in the trash to put in her grocery cart .',
#  'two black dogs running in snow with toys in their mouths .',
#  'there are 5 brown dogs on leashes with their owners nearby .',
#  'people under a tent .',
#  'a man in a yellow sweatshirt and black pants plays with a black poodle .',
#  'woman in blue shirt blowing very large bubble',
#  'a small child wearing a pink hat <unk> bluejeans <unk> and white shirt standing in a grass field .',
#  'a young boy in a red football jersey makes a large gesture as he stands in the midst of pumpkins .',
#  'pedestrians walk in front of an advertisement depicting a shirtless man in jeans .',
#  'the large <unk> dark colored dog is doing a climbing stunt outdoors <unk> while a man watches .',
#  'two bikers race uphill .',
#  'a black dog jumps in the air over the red hurdle .',
#  "a bullfighter skewers his prey just as he 's hit by the bull .",
#  'a dog is on the bed holding a toy soccer ball .',
#  'two people in shorts hike on the snow in the mountains with a lake in the background .',
#  'a boy holding a float .',
#  'a black dog running a course at a dog show',
#  'the rugby players in red are wrestling the player in yellow to the ground .',
#  'two young children on a skateboard going across a sidewalk',
#  'the lady wearing a black hat is taking a picture while the snow falls .',
#  'a man on horseback on a grassy field in front of mountains .',
#  'a brown dog runs in the woods with a serious look on its face .',
#  'a blonde woman with a red backpack in the snow .',
#  'two dogs chase each other across the snowy ground .',
#  'two young boys swimming in a pool of green water .',
#  'the boy in glasses is reading .',
#  'a man and a skateboard on top of a barrel .',
#  'a dog leaps for a toy on a road .',
#  'a black dog is running quickly along the ground .',
#  'two white dogs are playing with a brown dog and a ball .',
#  'a motocross bike is being ridden along a woodland path .',
#  'women participate in a skit onstage .',
#  'four boys mug for the camera in front of a brick wall .',
#  'a bearded man in jeans and a black shirt riding a bicycle in the street .',
#  'two dogs playing with the same red toy .',
#  'a race car drives through a dirt-covered racetrack .',
#  'a teenage boy on a bicycle does tricks .',
#  'a black standard poodle running through the snow in a fenced-in yard .',
#  'two women <unk> the younger one is looking down <unk> the older is drinking .',
#  'three children play in a water park .',
#  'a black and white dog with a blue toy in its mouth runs on a grassy surface just beyond a fence .',
#  'a brown dog jumps high in the grass .',
#  'three black dogs running after an orange ball .',
#  'a woman and a boy on a unicycle .',
#  'a march to protest the construction of a coal power plant .',
#  'small boy holding is arm out to balance himself while he goes down the fairground slide .',
#  'someone with a wave rolling over them .',
#  'three members of the red team are in the grass with a member of the yellow team .',
#  'a girl with her leg out on a lawn .',
#  'a big <unk> brown dog is shaking off while in the water .',
#  'a woman brushes dust and dirt off a possible find .',
#  'two people rafting down a river near pine trees .',
#  'two boys are playing flag football .',
#  'a young girl with braids is painting with water colors on a white paper on the wall .',
#  'a man in shorts skis down a hill .',
#  'a collie jumps over a hurdle .',
#  'the woman is wearing black shorts at a parade .',
#  'two boys are squirting water guns at each other .',
#  'a large tan dog jumps in the air over the grass in a fenced yard .',
#  'a boy in a striped oxford shirt points .',
#  'man in uniform stands near woman with purple hair .',
#  'a skier is falling into the snow .',
#  'a boy and a girl are dressed in colorful costumes .',
#  'two white dogs are playing in the snow .',
#  'a man playing rugby has the ball and tries to evade a tackler .',
#  'a person climbing a large moss-covered rock',
#  'a woman and children with their ice cream cones .',
#  'a large brown dog is crouching in a grassy field .',
#  'two people row a boat past rocks in water .',
#  'two men are sitting at a table outside a coffee shop .',
#  'a blond dog runs down a path next to a rhododendron .',
#  'a young boy jumps into water .',
#  'this dog is running through water on a beach .',
#  'two large dogs lying on their backs on a purple comforter .',
#  'a golden retriever has on a collar and a harness and has a muddy lower body .',
#  'a young girl wearing a tutu dances in a large room .',
#  'seven jockeys riding horses in a race .',
#  'two people are standing in shallow water <unk> waving sparklers around',
#  'a woman sites with her feet on the seats in a subway car .',
#  'black dog jumping over a white dog in a snowy path .',
#  'a lot of men and motorcycles float on a canoe .',
#  'a girl with her hair flying up from her head poses on a skateboard',
#  'a crowd watching a dirt bike race',
#  'a crowd walks along a sidewalk of a farmers market .',
#  'two opposing male players are chasing the ball in field hockey .',
#  'a man standing on a concrete platform with his arms wide open',
#  'the woman is holding a baby girl wearing a striped dress .',
#  'people sit against a wall',
#  'a curly-haired boy jumps up on a bed .',
#  'a group of skiers shown on a snow covered mountain .',
#  'a man prepares to interact with a lock for a bicycle while staring away from it .',
#  'a mother is holding her child on a train .',
#  'a baby crawls next to a street against a blue sky .',
#  'two children on the beach .',
#  'a child in a red shirt plays with fireworks .',
#  'a snowboarder in stripes .',
#  'a man in a red shirt at the top of a set of stairs with arena lights on in the background',
#  'two german sheperds snarling at each other .',
#  'a kid wearing safety gear stands on some material in the water .',
#  'the little boy in jean shorts kicks the soccer ball .',
#  'window shades cast light and shadow on a dog lying on a colorful carpet .',
#  'a dog chasing an animals tail on the grass .',
#  'a basketball player is jumping and about to dunk a ball in front of a crowd .',
#  'four young men are running on a street and jumping for joy .',
#  'a baby in a white and pink dress walks outside .',
#  'a black dog swimming in water near rocks .',
#  'the dog runs in the park .',
#  'a little boy in a swimming pool .',
#  'a sled dog team running from the perspective of the rider .',
#  'two young asian girls stand in the street and look concerned .',
#  'two women sit on a city train .',
#  'a motorbike jumping a pole .',
#  'a dark dog is in a body of water .',
#  'a white and brown dog is catching a red ball in its mouth .',
#  'a man is sliding down a huge sand dune on a sunny day .',
#  'the boy in the green and yellow shirt has a glove on and is going towards the ball .',
#  'a warmly dressed girl kicks up her leg outdoors .',
#  'a brown and black puppy stands by a camera .',
#  'someone is holding up a green fish for display outdoors .',
#  'four people <unk> in colorful kayaks <unk> are on the water on a sunny day .',
#  'two people stand on the top of a snow covered mountain .',
#  'a group of people are sitting around a table under a blue sunshade .',
#  'two racing dogs run in the mud .',
#  'a softball player swinging at a softball and missing it .',
#  'a man climbing a rock cliff .',
#  'a skateboarder jumps on brick stairs .',
#  'a young girl jumping out of the water at a pool',
#  'someone hikes through a snowy mountain range',
#  'speedskater skating a race .',
#  'a wrestler is falling onto another wrestler who is laying in a ring .',
#  'the blond haired girl wearing the flowered dress is swinging on a swing towards the blue sky .',
#  'a small dog stands next to a larger dog <unk> out in a field .',
#  'a man in red holds up a cellphone on the sidelines of football game .',
#  'a little kid holding a yellow and red soccer toy .',
#  'the dogs are joined together with a red harness .',
#  'a dog is jumping through the air in an open <unk> snow covered field .',
#  'a child in a white and orange outfit doing push ups .',
#  'a black and white dog is walking on a beach .',
#  'painting of albert einstein on a bear with child reaching up .',
#  'a sled-dog team works hard on this snowy trail .',
#  'two dogs are shaking water off .',
#  'smilling and laughing baby in a walker with fire engine airplane mobile and other toys on the floor',
#  'horses jumping a hurdle in a race .',
#  'a boy in an orange shirt and red hat is standing next to a girl with a white shirt and blue pants in the sand next to the ocean .',
#  'a young girl hula dances in front of a colorful backdrop .',
#  'two brown and white dogs are standing on a sidewalk .',
#  'a small dog chasing after a bucking cow',
#  'brown dog splashing into the water .',
#  'two football players are getting ready to tackle each other',
#  'a small dog is standing behind a camera .',
#  'a woman in a white dress walks toward the water on a beach with white boots in the foreground .',
#  'young girl in ponytail pets furry cat',
#  'two men with backpacks placed in front of them sitting in front of a railing .',
#  'the brown dog is in the waving water .',
#  'a man wears a floral bathroom as he stands over a trashcan .',
#  'the woman in glasses is smiling with the ocean in the background',
#  'a skier stands on his hands in the snow in front of a movie camera .',
#  'a little toddler in blue pants is crawling on the road .',
#  'a snowboarder in midair <unk> after jumping a ramp .',
#  'a couple pose on their wedding day .',
#  'sillhouttes of people in front of a mountain and in front of a window .',
#  "a young boy in a blue shirt and cap is jumping into a man 's arms .",
#  'two boys play with two dogs next to the ocean .',
#  'a brown dog holding a huge stick in its mouth running in the snow .',
#  'a group of children are in a water fountain .',
#  'a girl in a red polka dot dress and red headband playing with a pink handheld game',
#  'a dog swimming in a pond .',
#  'a medium sized brown dog is running through an open white wooded area .',
#  'a baby in pink <unk> striped clothing is sitting near an older lady wearing red and black .',
#  'a man with an electric guitar smokes a cigarette sitting outside .',
#  'the lady has a tattoo .',
#  'a girl flies through the air as a man stands with his arms outstretched .',
#  'a soccer ball is above the head of a man wearing black shorts and red and black striped shirt .',
#  'two men in midair fighting in a professional wrestling ring .',
#  'two men look out as one is holding binoculars .',
#  'a man pushing a baby stroller at the beach <unk> a woman with a little boy ahead .',
#  'man is diving onto his wakeboard .',
#  'a golden retriever splashes in the water .',
#  'a young laughing girl and a boy are playing on a big drum .',
#  'a man and a boy wrestle inside a house .',
#  'a dog is playing fetch with a ball .',
#  'a man with blue boxing gloves is throwing punches .',
#  'a tan animal is being swatted in the face by a brown and white bull .',
#  'a brown chow mix dog is standing in front of a van with euro plats in the middle of a messy yard .',
#  'three boys in size order getting wet next to a wall',
#  'a black dog nurses white puppies .',
#  'a woman screams as a man throws a deck of cards .',
#  'the kid is playing hopscotch .',
#  'children and adults play with a sprinkler .',
#  'a young boy in a blue jacket pulls something black out of a fabric bag .',
#  'two boys <unk> surrounded by paper pieces <unk> hold a third boys shirt to prevent him from grabbing a bag .',
#  'a man reaches toward dunking a basketball while an audience watches .',
#  'a man stands on a four-wheeled board attached to a harness .',
#  'a little boy puts a bat on his forehead and spins around .',
#  'a woman in semi-formal attire is sitting on a concrete wall .',
#  'a very little child swings on a tire swing .',
#  'a man is clapping at the base of the washington memorial .',
#  'the obama supporter wears a black jacket and brown hat .',
#  'a brown horse jumps through its paddock .',
#  'an artist paints clouds onto a canvas .',
#  'a cow herd grazing in the pasture with a dog running in the foreground .',
#  'a man wearing a blue shirt crouches on a rocky cliff .',
#  'a young boy wearing a red coat is playing in a long tunnel .',
#  'people marching on the grass in yellow shirts carrying drums',
#  'two mountain climbers stand on the top of a mountain looking around .',
#  'extreme bmx rider defying gravity',
#  'four children are running and playing tag .',
#  'a man dressed in blue standing in front of a colorful fruit and vegetable stand',
#  'two small dogs follow a larger dog with a tennis ball',
#  'three women are minding their own business on a bus in the city .',
#  'a black dog nursing black and white puppies .',
#  'a black dog plays in the water .',
#  'a girl climbing a tree .',
#  'man playing an electric guitar on a sidewalk and smoking a cigarette .',
#  'three dogs play in a field near a house to the right .',
#  'a woman in white is pointed at by a sign on the road saying look right .',
#  'a black dog jumps over a show jumping hurdle .',
#  'three children jumping into a pool .',
#  'two men play basketball <unk>',
#  'a black dog wearing an orange collar is entangled with fishing wire .',
#  'a man looks through his binoculars while another man holds a drink .',
#  'a man lifts a child up to reach the bars at a playground .',
#  'two children ride tricycles in a race .',
#  'a young curly brown headed boy is jumping into the arms of a woman in a pool .',
#  'a dog lies on the steps outside a building .',
#  'someone on a motorcycle leaning into a turn .',
#  'there is a notre dame quarterback dropping back into the pocket at a game .',
#  'a german short-haired pointer rests on a rug by a sunny window .',
#  'a dog swims in the aqua water .',
#  'a woman embraces a smiling man at a party .',
#  'the boy is playing drums .',
#  'the young boy learns how to ride a bike with his dad .',
#  'a dog running with his tongue out .',
#  'the girl in blue kicks the soccer ball .',
#  'a young girl in a white dress',
#  'a child in a pink hat on a pink surfboard .',
#  'a brown and white dog playing with black dog .',
#  'a black and white dog is running through a cow field .',
#  'two people in a field looking off-camera .',
#  'a smiling boy swims <unk> with only his head above the water .',
#  'the little girl is playing at the playground .',
#  'the woman in the red jacket looks as if she was buying something from the open air vendor .',
#  'two men sit on a bench in front of a three tier fountain .',
#  'two young men play basketball while crowd looks on',
#  'a woman in a red business suit sits on a step sharing food with a man in a leather jacket .',
#  'a boy standing on a beach .',
#  'a white bird with yellow feet is flying over water .',
#  'two people carrying colorful baskets and blankets walk near a building .',
#  'two motorcycle racers ride along a racetrack .',
#  'a child in purple winter gear is on a red sled .',
#  'a man on a city street in a santa suit and wrestilng mask .',
#  'a dog happily plays in tidal overflow on a cloudy day .',
#  'a dog treads through a shallow area of water located on a rocky mountainside .',
#  'two children in white outfits and red protective gear spar on a mat .',
#  'two men posing with their legs up with a train in the background',
#  'small girl petting an animal .',
#  'a driver is sitting in a team penske race car .',
#  'a man and woman sit on cement stairs outside of a store .',
#  'a goalie is guarding the goal .',
#  'a reddish brown dog running .',
#  'a young boy playing with a blue ball standing on a sidewalk',
#  'a large white dog is bounding through a snowy field .',
#  'a surfer rides out a wave .',
#  'man teeing off on a golf course with a large building in the background .',
#  'a little girl in blue panes dances on the grass .',
#  'a dog plays on a beach .',
#  'a dog jumps to catch a ball in a grassy field .',
#  'two boys preparing to jump off a pier located on a large body of water .',
#  'four boys playing on the inertia wheel at a park .',
#  'a black dog is shaking off water .',
#  'a man in an orange shirt flips his skateboard on a suburban street .',
#  'a black and white dog is running in a grassy garden surrounded by a white fence .',
#  'a boxer is practicing making hits by targeting the gloves of his partner .',
#  'a man sits on a bench near a sidewalk <unk> reading a newspaper .',
#  'the two children are being sprayed by water',
#  'a man wearing a black hat walks along a road next to a building .',
#  'a woman wearing a red and white gown holds a long scarf behind her .',
#  'a man is doing a trick on a skateboard in a covered area .',
#  'a girl in a bathing suit plays on the surf .',
#  'two girls play on a skateboard in a courtyard .',
#  'a little boy wearing a blue shirt is playing around large tires .',
#  'a group of people in protective gear .',
#  'girl is performing onstage with a hula hoop surrounded by many balloons .',
#  'a child looks into a giant bubble .',
#  'two men engage in a professional wrestling match .',
#  'five brown dogs are walking down a grassy path .',
#  'a man holding plastic toys looks away while a man wearing a white hat smiles at the camera .',
#  'the white and black dog leaped into the air and off the snowy ground .',
#  'a dog gnaws on the strap of a camera .',
#  "a dog jumps up to take something from a woman 's hand .",
#  'a guy is on his bicycle .',
#  'a curly haired girl is dragging a grey inflatable raft with a red paddle into the water .',
#  'the hawaiian singer belts out a tune .',
#  'a person is climbing a cliff wall <unk> over a rocky shore <unk> using a rope .',
#  'two men under a dog hanging by its mouth from a rope .',
#  'the boy is playing uno .',
#  'a bearded man and a bald man carrying prizes at a carnival .',
#  'four people are walking on a bridge .',
#  'a dog sitting in the grass <unk> with his tongue out',
#  'a young boy rides a blue and yellow merry-go-round with an adult male hand in the foreground .',
#  'a pale tan dog with a ball in its mouth waking in grass .',
#  'a woman with a toddler in a striped dress',
#  'a woman in a white shirt standing on a street',
#  'a man on a dirt bike jumps slightly as he crests a rise .',
#  'the small girl in the hello kitty gloves and red snowsuit smiles while sitting on a large snowball .',
#  'little dog chases ball at farm',
#  'a woman carrying a white ball is running behind a small boy .',
#  'three women dance before a flag .',
#  'a man is riding a board in the ocean and is being pulled from above .',
#  'a baby carrying a ball in stands in front of a house with a hose in the background .',
#  'woman carrying her shoes on a beach .',
#  'a shirtless man is doing a skateboard trick .',
#  'a small group of people are in a small red boat and it is in the air over the ocean .',
#  'a dog walks across a tall ladder .',
#  'the little boy is playing by tires .',
#  'people outside an ice cream shop that has summer decorations for sale .',
#  'two men stand outdoors in the city night .',
#  'a girl in a yellow bathing suit from a cliff looks at a person in the water .',
#  'a child in a jean jacket smiles while playing in a tree .',
#  'a young man <unk> bearing his <unk> <unk> and other people are gathered in a city street .',
#  'boy covered in finger paint .',
#  'two men sitting in front of a railing are looking at something .',
#  'black dog chasing brown dog through snow',
#  'a girl jumping over a red punch bag .',
#  'a man walks across the tightrope .',
#  'two football players <unk> one in an orange jersey and one in a white jersey <unk> play on the field .',
#  'a man jumping on the hard ground .',
#  'there is a young girl in a yellow dress and a young boy in a white suit standing in a field of grass .',
#  'a young boy in a baseball cap jumps into the arms of a man wearing a blue shirt .',
#  'a canoe in the distance on a lake as seen from another canoe .',
#  'man in blue sport uniform with basketball in right hand attempting to score basket while being blocked by player in white uniform .',
#  'a dog splashes through the water .',
#  'the boy and girl are wearing swimming goggles .',
#  'a beagle looking over his shoulder as he stand on a sandy slope .',
#  'a man with tattoos is lounging on a couch holding a pencil .',
#  'a large white bird flying over water .',
#  'a woman leans against the wall while a camera operates next to her .',
#  'a small child plays with a batman toy car',
#  'a dog leaps high to catch a ball .',
#  'group of people waiting in line at an ice cream stand .',
#  'the little girl in a pink shirt and jeans is climbing up a rock climbing wall .',
#  'a football player in mid stride holding a football .',
#  'girl slinging water out of hair while in a pool .',
#  'an older couple jogging by the water',
#  'two dogs wrestle with each other with their teeth bared .',
#  'a girl in pink picks flowers .',
#  'a woman in a red sweater walks past two younger women who are chatting .',
#  'boy with a painted face is walking around a track .',
#  'a young child partially concealed by a pile of colored balls .',
#  'two black men playing basketball in a gym .',
#  'a man wearing an orange uniform is working outside with a hose .',
#  'three people in reflective white on bikes .',
#  'a girl with a striped shirt with bread in hands in front of mouth .',
#  'a skateboarder jumps on an urban alleyway .',
#  'a beagle is playing with a tennis ball .',
#  'a woman is covering her eyes with her hands .',
#  'two girls dressed in costume with purple flowers in their hair strike a pose for the camera .',
#  'three men are playing a game of basketball',
#  'a brown dog is splashing water in a yard .',
#  'a man in a blue shirt <unk> cowboy hat and a cross <unk> walking in front of a carnival or amusement park ride .',
#  'a man wearing sunglasses is sitting in a chair .',
#  'a man dressed as a pirate is smiling for the camera in between a male and a female .',
#  'someone fires a bullet from a handgun into the woods .',
#  'a german shepherd leaps in midair .',
#  'one climber helps another in the snow .',
#  'dogs playing in the snow',
#  'a baby playing in a toy',
#  'a little girl in a dress with pink flowers swings on a red-seated swing .',
#  'the man is wearing a white shirt and sunglasses .',
#  'a person stands next to a snarling brown and black dog while a light brown dog stands up .',
#  'two young soccer players race to the goal .',
#  'the brown dog has a stick in its mouth .',
#  'a baby chews on plants .',
#  'the tennis player holds his racket up anticipating the ball .',
#  'a man on a white waterskiing ramp on a lake',
#  'a man and are playing cards but the man has thrown some cards in the air',
#  'a young kid is standing up on the merry go round .',
#  'a blond woman is throwing a stick for her orange dog <unk> who is leaping to get it .',
#  'a woman kneels in the dirt with paleontologist archeologist tools .',
#  'a boat containing people is suspended by a cable .',
#  'there are three policemen and a police motorcycle .',
#  'two rodeo clowns <unk> one young and one an adult <unk> waiting their <unk> .',
#  'a quarterback ready to pass the football in the middle of a play .',
#  'the woman is jumping a long distance while people watch .',
#  'a woman is holding a jar of mustard and a boy is looking at a tray of hamburgers .',
#  'a man and a woman in a silver coat are on a city sidewalk with their backs to the camera .',
#  'a white dog rests its head on the patio bricks .',
#  'the man wearing glasses <unk> with a cigarette in his mouth <unk> sits in a chair .',
#  'two black dogs in the snow .',
#  'a football player runs across the field as the referee blows his whistle .',
#  'three women at an art gallery <unk> two of the women holding wine glasses .',
#  'a dog is taking a dive into a body of water .',
#  'a young football player in a muddy <unk> yellow and blue uniform carrying a football with other muddy players run behind him .',
#  'a dog runs across a barren ground casting a large shadow .',
#  'a boy in green trunks slides down a water slide .',
#  'a dog is distance jumping into a pool of water while spectators are watching .',
#  'three women dancing in robes .',
#  'a woman at an outdoor food stand .',
#  'a man jumps in the air while performing a stunt on his skateboard .',
#  'dogs and their masters gather on a dirt trail .',
#  'a kid cross-country skis wearing the number `` 93 `` .',
#  'man sitting at a table in a restaurant .',
#  'a man stands at the top of a flight of stairs at the entrance to a stadium .',
#  'the drag racers take off the starting line .',
#  'an athletic girl in an orange uniform is on a playing field of green grass and swinging at a ball .',
#  'a wrestler poses in front of a series of explosions .',
#  'two people standing in tree on a sunny day',
#  'a large vehicle drives through a mud puddle .',
#  'a small boy stands on a cement stump in a park with his hands on his head .',
#  'two men appear to be having fun rollerblading down a sidewalk .',
#  'a boy plays soccer in a field near an apartment building .',
#  'a guy making a snowboarding move on a slope .',
#  'a baby is laughing .',
#  'a long haired skateboarder is airborne above a set of cements steps and a metal bannister .',
#  'a windsurfer skims the water with his outstretched hand .',
#  'the boy is kicking a soccer ball .',
#  'a man in a brown vest and glasses plays with a brown dog .',
#  'a girl dressed in a red and black top with black pants is sitting on a wall .',
#  'a man in an orange hat starring at something .',
#  'two dogs are running in a field .',
#  'a girl jumps into the air while another girl watches .',
#  "a child is riding on a man 's back .",
#  'little boy runs downhill at camera <unk> <unk> in background .',
#  'a black cow and a brown cow being chased by a dog',
#  'one young girl dressed in red polka dot outfit plays with toy .',
#  'a man on a boat and has a beautiful sky above him .',
#  'two people holding hands and walking in a field .',
#  'a man sitting on an old piece of wood outside .',
#  'two women walking down a dirt road with a man far behind .',
#  'a small child climbs a large rock while someone casting a shadow takes her picture .',
#  'three men stand on the beach <unk> fully clothed .',
#  'brown dog crouching in grass looking up',
#  'a tan dog jumps and runs in a field .',
#  'the skier is leaning forward in the snow .',
#  'a man with a white headband playing drums .',
#  'a young girl twirls her fluffy purple skirt .',
#  'a man in sunglasses sits on rocks .',
#  'a crowd surrounds a grounded hot air balloon .',
#  'a little girl and boy play frisbee together in a grassy area .',
#  'two children play soccer on green grass .',
#  'asian boy puts his head inside a large bubble .',
#  'a girl wearing pink pulls weeds .',
#  'a young girl climbs a tree .',
#  'man skiing over a barrel in a snowy area .',
#  "a girl holding a crocodile 's mouth closed",
#  'a woman pulls an inflatable boat into the water .',
#  'person hiking up a rocky slope with white objects in front of them .',
#  'two blonde boys <unk> one in a camouflage shirt and the other in blue <unk> are having a water fight .',
#  'a man and a woman are looking at a painting in a gallery .',
#  'two brown dogs are playing in a field .',
#  'a child in hawaiian clothing jumps and poses in a low cut yard nearby a fence and building .',
#  'two large black dogs with red studded collars pulling on ends of a white rag on porch',
#  'a sooners football player moves quickly on the field as another player runs .',
#  'a girl with red hair is sitting on a crocodile holding its jaw .',
#  'a group of brown dogs are standing on a road with 3 people .',
#  'blurry photo of man and woman .',
#  'a brown dog and a black and white dog stand beside a hole in the dirt .',
#  'two boys fight for the ball .',
#  'a large white bird swoops over water .',
#  'two people dressed up in white sheets and pink gloves stare at a snow covered glacier off in the distance .',
#  'two girls doing cartwheels <unk> while other children look on .',
#  'the skateboarder is leaping over a green barrel .',
#  'a woman is holding a stick in the air <unk> while a dog jumps up .',
#  'a man with a purple hat is climbing a rock .',
#  'three football players are tackling a red uniformed football player during a football game .',
#  'a toddler in a blue bandanna playing with a set of rings on a stick .',
#  'there are three people in jeans and shirts standing outside with spray cans .',
#  'people travel up the elevator together .',
#  'the girls are playing soccer .',
#  'an olympic winner takes home two medals .',
#  'boy running through the water at the beach',
#  'two children playing on rocks',
#  'bicyclists stay in a line as each wear different color suits .',
#  'a cheerful small girl dressed in a white dress with flowers runs on a grassy area with her arms in motion .',
#  'a snowboarder doing a jump on a k2 snowboard .',
#  'two motorcyclists on a track .',
#  'a climber is hanging on a rocky ledge high over a bridge .',
#  'a man with jersey 23 is dunking the ball at a basketball game .',
#  'three dogs in a field looking at something in the grass .',
#  'a small white dog is running through the dirt right on the outside of a patch of grass where two people and another small black dog are playing .',
#  'a young boy and girl playing .',
#  'a group of women in pink dresses <unk> walking across a street .',
#  'a girl runs through an obstacle course outside as some boys watch .',
#  'a young girl plays the electric guitar on her bed .',
#  'the man wearing a backpack and a hat <unk> stands on a ledge overlooking a city .',
#  'the black dog runs with a ball with two smaller dogs behind it .',
#  'a boy in a blue top is jumping off some rocks in the woods .',
#  'a group of people riding a yellow roller coaster .',
#  'large stuffed bears hang above a carnival game .',
#  'the black dog waring a red collar is running through the water with a ball in its mouth .',
#  'a group of people sit on an outdoor patio with lots of potted plants .',
#  'man on skateboard on top of rust colored barrel in darkened area .',
#  'two kids smiling underneath a red flower .',
#  'a person wearing a blue hat takes a photo in the snow .',
#  'a snowboarder wearing red is descending a snow covered mountain .',
#  'a black dog and a brown dog with a yellow foam soccer ball toy on a grassy field',
#  'a black dog with a stuffed animal in its mouth is running and jumping through a snowy field .',
#  'the black dog carries an object in the snow .',
#  'two boys and two dogs are playing in the sand and water at the seashore .',
#  'a little boy is holding a lit sparkler in the backyard .',
#  'a person is being swept to the ground by waves .',
#  'two dogs stand side by side in the yard .',
#  'yellow dog running through bushes on path .',
#  'two dogs fight over a stick in a flooded field .',
#  'a man who is dressed like a wrestler walks while people take his picture .',
#  'an unknown animal or person is swimming in a natural lake setting .',
#  'little girl on skis',
#  'a black and white dog jumping out of the water and a brown dog shaking off .',
#  "snow covers the ground and a young boy 's jacket .",
#  'the person is in a conoe and holding a paddle in front of some mountains .',
#  'a young boy is bursting out of a pile of dead leaves .',
#  'a child on a kiddie swing being pushed by a woman',
#  'a heron is flying through the air near foliage .',
#  'a man in a red coat and hat talks to another man in red .',
#  'a woman sitting in a field of flowers',
#  'a man has a pink ribbon around his arm .',
#  'a man with a wake-board is diving over a surface that is not water .',
#  'a man is bouncing on a trampoline next to tall buildings and a church .',
#  'three men on wooden boat in front of buildings',
#  'a woman in a bright safety jacket is standing next to large pipes .',
#  'a skinny girl in large boots is standing by the roadside .',
#  'a black and brown dogs pulling a red leash .',
#  'a woman is dancing onstage in front of a screen .',
#  'a group of teenagers are dancing on a wooden floor .',
#  'a man in blue goggles is in the swimming pool .',
#  'a man wearing a white shirt <unk> gold cross <unk> and a cowboy hat is standing in front of a roller coaster .',
#  'child in yellow shirt with head inside of a large bubble .',
#  'two brown dogs run through the grass together .',
#  'a rider on a white horse is in the middle of a jump over a hurdle .',
#  'a couple posing together each smiling',
#  'the man in the backpack looks to his left .',
#  'two samoyads play in the snow .',
#  'two boys are swimming underwater in a pool .',
#  'two people wear life jackets in a rowboat .',
#  'a smiling woman stands in front of a body of water with water birds .',
#  'the children are near a large pile of sand that is next to the water .',
#  'a woman is running beside a dog that is jumping over a red and white obedience training fence .',
#  'the boy wearing the blue hooded top is holding a baby goat in his arms .',
#  'a group of dogs runs down a path through dry grass and bushes .',
#  'a man and a guard laugh together .',
#  'a group of happy young men and women hold flags with chinese writing on them .',
#  'a man in orange shorts holds a child up on play equipment .',
#  'a young man and woman are walking along an outdoor market .',
#  'a boy on a skateboard is at the top of a ramp .',
#  'a young boy wearing mickey mouse clothes in a jungle gym .',
#  'adults in winter jackets and hats swing brooms at a little yellow ball while a black dog looks on .',
#  'a child is performing with a toy while onstage with a colorful balloon backdrop .',
#  'a female in blue jean shorts and a black top sitting in a wicker chair .',
#  'a black and tan dog in the snow',
#  "the woman places a ball into the jumping dog 's mouth .",
#  'the white dog next to the brown dog is wearing a christmas headband .',
#  'a woman in a dress plays violin outside .',
#  'a white dog is following a black dog through the grassy area .',
#  'two men and a woman smile at the camera .',
#  'blonde scottish terrier with ball in mouth standing on blanket',
#  'a dog jumps in the field .',
#  'a person on a dirt bike is in midair making a jump on a dirt track .',
#  'a girl playing softball <unk> taking a swing .',
#  'two dogs with a rag in their mouths',
#  'a dog running on a sunny <unk> green lawn .',
#  'a black dog and a black and white dog are running on sandy ground .',
#  'the snowboarder is doing a jump .',
#  'a football player in a gold helmet is running with a football .',
#  'a person wearing a yellow helmet is climbing a cliff .',
#  'three men sit together while one looks at a book .',
#  'a man reads the paper on a wood an iron park bench .',
#  'a small brown dog paws at a white ball',
#  'a man sitting in a blue metal chair .',
#  'a long woman wearing a white helment crossing a chain linked bridge',
#  'a brunette girl wearing sunglasses and a yellow shirt',
#  'a person is suspended by wires and poles against a blue sky .',
#  'the man with pierced ears is wearing glasses and an orange hat .',
#  'a little boy hits a baseball while his family watches',
#  'a little girl in a pink tutu gets ready for ballet dancing <unk> a boy in a spider-man shirt behind .',
#  'two children are running towards the ocean on a beach .',
#  'young boy blows into a hose while sitting on the deck .',
#  'person on snowboard in the air doing a jump',
#  'a boy pulls back a swing with a little girl on it',
#  'the teenage boy and girl are smiling under a red flower .',
#  'two people in jackets are rowing a canoe down a river .',
#  'two children are in costume in a dance studio .',
#  'a crowd watches the start of a drag race at twilight .',
#  'two dogs are fighting in the snow .',
#  'two bald ladies in red dresses and matching jewelry laugh .',
#  'two young children are walking across an open field .',
#  'a group of young people busk on a street corner .',
#  'the boys draw in the sand with sticks .',
#  'several workers standing in a partially constructed building behind street sign',
#  'a small dog and a large dog carrying a stick in its mouth run outside .',
#  "a woman looks over a table of organic vegetables at a farmer 's market .",
#  'the man with brown hair in the black sweater is covering his face with his hands .',
#  'a female hurdle-jumper is caught in midair clearing a hurdle in a track-and-field setting .',
#  'a man in woman dressed warmly pose for a picture .',
#  'a dog on a green hillside .',
#  'a young boy wearing glasses has his hair set to stand up .',
#  'lots of people are playing in the river that runs through the city and in the sandy park beside it .',
#  'a man stands on top of an elephant in the water .',
#  'we can not see the face of the girl with the white t-shirt and blue jeans .',
#  'two hikers <unk> one wearing a bikini walk on snow .',
#  'a woman with a green shirt and a woman with an orange shirt posing with outstretched arms',
#  'a crowd watches as two formula one cars leave the starting line .',
#  'a skateboarder midair with his skateboard .',
#  'three children are jumping into the water under a palm tree .',
#  'a man stands on a hill at dusk .',
#  'a child in front of his own reflection turning towards the camera and smiling .',
#  'a dog jogs through the grass .',
#  'two guys are playing with two dogs on the beach .',
#  'a young couple in wedding outfits poses for a picture .',
#  'a blue <unk> red <unk> and yellow plane does a loop in the air .',
#  'two middle aged women stand for a picture near a forest .',
#  'a woman hugging a man at a formal occassion .',
#  'a man riding a red motorbike near a large crowd of people by some tents .',
#  'two blond boys play with legos from a clear plastic bin with a sofa in the background .',
#  'there are many different colored balls .',
#  'a young girl is laying in the grass posing for the camera',
#  'a group of people on the sidelines of an atv race .',
#  'a skier races down the mountain .',
#  'a person and their tan dog go for a ride in a rowboat .',
#  'two dogs playing in the snow .',
#  'a child hits a baseball into a net .',
#  'a young boy diving through the water with his eyes open .',
#  'a girl skips over to the fence .',
#  'a woman in a brown vest is walking on the snow with an animal .',
#  'three women talking <unk> holding glasses of wine <unk> with paintings in the background .',
#  'a man is rock climbing .',
#  'a man with a yellow shirt and gold sun mask on his face .',
#  'woman stands on fallen trees near winding river taking photographs of animals .',
#  "the young boy jumps into the man 's arms .",
#  'a man on the beach in jeans looking at his camera .',
#  'a small white dog jumping to catch a tennis ball .',
#  'the white dog stands in the snow wearing a black jacket .',
#  'a black and white dog stands on the grass with a baseball in his mouth',
#  'a woman in a blue shirt guides her dog over an obstacle .',
#  'a woman taking pictures of the surf and a child in the foreground .',
#  'a boy gets flipped into the river by another boy .',
#  'a man in green kick a soccer ball while a man in purple and white is falling down .',
#  'man wearing boys will do boys shirt waves at camera during gay pride parade',
#  "the black dog 's head is poking up out of the water .",
#  'a blonde child riding a tire swing .',
#  'the woman is guiding a brown and white dog over a tall white fence on an obstacle course .',
#  'a bird with a long orange bill drinks water .',
#  'a racer on an atv leaves the ground in a jump .',
#  'black dog jumps from hay ball to hay ball .',
#  'a pale colored dog runs through a body of water .',
#  'a man in a red striped soccer shirt heads a ball .',
#  'a trick cyclist takes air .',
#  'a man without a shirt is walking on top of lots of rocks .',
#  'a man with a canoe is on the beach with a tent set up .',
#  'a black and tan dog is running along a series of stone walkways spaced between grass .',
#  'a skateboarder goes down some stairs .',
#  'the long black shadow casts a image on the rock while the young girl climbs the rock .',
#  'two dogs play with one another outside .',
#  'a man stands at the top of a stadium staircase .',
#  'several people shopping at an outdoors market .',
#  'a man wearing a cowboy hat and a gold cross around his neck',
#  'people ride up an escalator .',
#  'a man takes a picture of another two men in a crowd .',
#  'shoppers in a fruit and vegetables market looking around .',
#  'baby wearing red hat in car seat .',
#  'a little boy in orange pitching at a baseball game .',
#  'several people work on a machine .',
#  'an asian boy and girl walking amongst a crowd with trees over their path .',
#  'a dog that is down in water is shaking off .',
#  'women who look alike are performing on a stage .',
#  'a motorcycle rider is slightly airborne on a motocross circuit',
#  'a brown boat is packed with goods and people .',
#  'a group of men are changing the shells on a cannon .',
#  'a shoeless strapped in individual jumping with rubber bands attached is airborne .',
#  'a dog is bounding through tall grass .',
#  'a tall <unk> thin <unk> brunette girl wearing combat boots standing on a sidewalk .',
#  'a wide eyed guy in a blue jacket is holding a beer and standing next to a guy holding his nose .',
#  'a miami basketball player .',
#  'skiiers on snow cappedhills',
#  'a man rows his boat below .',
#  'a woman wearing shorts is holding a tan dog while a white dog jumps up in front of her .',
#  'a man in a wetsuit and helmet in front of a red wall .',
#  'girl wearing purple jacket rides a red snow sled .',
#  'a little girl with mud on her face cries .',
#  'a woman in jeans and a woman in shorts are petting a baby kangaroo .',
#  'a group of people painting the side of a building in an array of colors .',
#  'man rowing a boat .',
#  'a person holding a frisbee just out of reach of a white dog on a rural road',
#  'an animal is attempting to cross the river .',
#  'a girl bends down to paint something underneath her .',
#  'a woman read the paper and drinks from a coffee cup in front of an art gallery poster .',
#  'two men wearing hats are shown at the front of a crowd of people .',
#  'a person kayaking down a small waterfall .',
#  'two people are walking along a long cannon on a tank .',
#  'a person descends a rope from a cliff into the ocean .',
#  'a wet black dog shakes itself off .',
#  'people running a race and the guy in grey is in the lead .',
#  'a brown dog is running through a wooded area .',
#  'a rollerblader skating inside a tube .',
#  'a man wearing a large backpack is sitting in the grass near a lake .',
#  'dogs walking in the grassy field .',
#  'a girl swings a bat during a softball game .',
#  'a boy and his bike leaps into the air .',
#  'black and white dog jumping up in the snow .',
#  'a woman walking over a bridge with tall grass on either side of her .',
#  'children playing in a pool .',
#  'a sooners football player is tackling an opposing player .',
#  'a young boy jumping into a pool that says `` no diving `` .',
#  'a couple hurrying past an urban ice skating park .',
#  'a man and woman are sitting on concrete stairs .',
#  'the black dog and the brown dog appear to be wrestling .',
#  'many people at a gathering .',
#  'tourists pose for camera at night .',
#  'a man in a wetsuit is surfing on a green surfboard .',
#  'a man with a black shirt that says `` genetic freak `` is sleeping on a bus .',
#  'a tan and black dog walks happily through a field .',
#  'a hiker is climbing up a snowy mountain .',
#  'a man talks on a cellphone while holding an obama campaign sign .',
#  'the little girl is playing with her shoes off .',
#  'a diver midair against an urban background .',
#  'the person in the striped shirt is mountain climbing .',
#  'a man wearing a pink ribbon on his arm has been splattered with yellow paint .',
#  'a race car drives on a track while several people watch from behind rope .',
#  'a black and white dog playing in the snow together',
#  'older gentleman in a red coat and black and white polka dot scarf .',
#  'while holding tight to the ball <unk> the man in red socks is getting tackled .',
#  'man on a motorcycle performing a trick high in the air .',
#  'people on the beach and a kite in the sky .',
#  'a small brown dog is running across the grass wearing a purple and green coat .',
#  'a little boy in a yellow jersey playing in a playgym .',
#  'white fluffy dog running in the dirt .',
#  'two opposing soccer players run toward the ball while a goalies prepares a block .',
#  'an older man in a blue hoodie is sitting down next to his bags .',
#  'a man is kayaking down a waterfall .',
#  'a man in wetsuit jumps towards a wet bride .',
#  'a wet dog is shaking off water .',
#  'peoople stand outside a building near a street .',
#  'a dog with mouth open to catch the red ball .',
#  'women are riding horses in an arena carrying the flags of canada and the united states .',
#  'a miniature dachshund has an apron on its back .',
#  'a small boy in yellow rides a bike very fast on a brick road .',
#  'three smiling children running indoors .',
#  'a woman skiing down a snowy mountain with a brown dog on a lesh running with her',
#  'four boys pose for the camera .',
#  'a dog zips along the beach .',
#  'the fuzzy dog runs through the water .',
#  'a number of people standing and laying under a mountain covered in snow .',
#  'a young boy wearing a red shirt hanging around a brown pole',
#  'a small dog wearing a purple and green cape',
#  'a bunch of people playing soccer .',
#  'children are practicing judo on red and white mats .',
#  'a matador in white and gold clothing and pink sock is getting hit by a raging bull',
#  'a little girl in white leaves her boots behind as she walks in the sand .',
#  'a woman is wearing a green striped shirt and a brown skirt .',
#  'a black dog runs on green grass with its mouth open .',
#  'a group stands on tan checkered tiles .',
#  'two dogs playing on a beach .',
#  'a brown dog with a tiny soccer ball in its mouth is standing on a blanket',
#  'children at a park .',
#  'a woman wearing purple and green is spinning a green hula hoop around her waist .',
#  'a boy in a white t-shirt is splashing in shallow water .',
#  'an asian boy in a red shirt holds onto an aqua balloon .',
#  'two men in blue jumpsuits <unk> one holding a bandaged girl',
#  'a young woman watches as a young blond boy swings in a chair swing with buildings visible in the background .',
#  'two dogs run across the grassy field .',
#  'a child in a red hoodie and black pants ice skating in a rink .',
#  'four boys posing for a picture with pumped fists',
#  'the girl is holding a blue balloon on a busy street .',
#  'a golden retriever is shaking off some water',
#  'toddler boy wearing airplane shirt <unk> in stroller with large beads .',
#  'four kids holding hands jump into a swimming pool .',
#  'a woman dances along with a dancing video-game projected on large screen behind her .',
#  'a white dog is standing on a grassy hillside .',
#  'the people are showing their faces through frames .',
#  'a man in green and black gets muddy on a dirt bike .',
#  'a man practicing boxing',
#  'a group of people pose for the camera in front of some laundry and greenery .',
#  'two girls are doing cartwheels as other children stand around watching .',
#  'two kids ride an amusement park ride .',
#  'a boy wearing a helmet flips up his scooter as he skates between orange cones .',
#  'two women are looking at a monitor with a long antenna .',
#  'the number 52 motorcyclist in a blue and black helmet is going around a corner .',
#  'a little girl holding hands with her ice skating instructor .',
#  'person wearing a flowered robe holding a cup of coffee leaning on trashcan',
#  ...]

# %%
len(true_captions), len(pred_captions)
# Out:
# (6065, 6065)

# %%
combined = ['true|predicted']
combined.extend([true_captions[i] + '|' + pred_captions[i] for i in range(len(true_captions))])

# %%
combined
# Out:
# ['true|predicted',
#  'a toddler is sitting down .|a little is standing on a',
#  'man carrying a tool box on a sidewalk|a is a woman in . a red . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'two men are sitting on a bench looking at a water fountain|a people are playing on a skateboard . . the . . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'two people watch tv from over a white ledge .|a people are in',
#  'a young woman crosses a bridge through a field of tall grass .|a man man in a white on a field . a . .',
#  'two youn boys lay in a dog house with their dog .|a dogs playing in a the field . . a . .',
#  'a dog in the snow carrying a tree limb in its mouth .|a dog is a snow . a green . . the mouth .',
#  'a girl sits and laughs while in a kiddie pool .|a little in in a in a the red . .',
#  'a boy wearing black swimming trunks is standing in a fountain .|a young in a and in in running on the field .',
#  'the brown dog pulls a skier across snow-covered ground .|a dog and is in ball . a . .',
#  'the owner tries to hand a deflated ball to his dog .|a man is in a and white . . a mouth .',
#  'three climbers on rocks near waterfall .|a people is a in a .',
#  'a black dog carries a white toy in his mouth and walks on the snowy field .|a black dog running a black dog . a mouth . a . the grass . .',
#  'four children .|a people are',
#  'a man in jeans is using a yard work tool just above some pavement steps .|a man is a and standing a trick . . a a a . . .',
#  'a child in a gray t-shirt is bouncing a basketball on a basketball court .|a young in a red shirt in standing a man . a red . .',
#  'a dog races while wearing number 6 .|a man is in a a and in',
#  'a woman holding a ball chases a small boy running in the grass .|a young is a boy in a red girl in in a grass .',
#  'a brown and white dog with big brown eyes with a dishtowel in his mouth on a hardwood floor .|a dog dog white dog is a black dog . a white . a mouth . a beach . .',
#  'a skateboarder ollies .|a man is a',
#  'woman with two medals around her neck <unk> holding up seven fingers .|a in a people are a . . in a . . .',
#  'a little girl holding a frilly white dress out for the other little girl to examine .|a man girl in a blue in . in . a grass . a in a .',
#  'members of two soccer teams struggle on the field to get the ball .|a in people men in in in the grass . the . . .',
#  'an elderly woman sits in a chair and wear a winter hat and coat .|a a girl in in a red . a . man . . a .',
#  'dog standing in grassy sand dune .|a is in the snow . .',
#  'a black guy in a apron grilling cornstalks .|a man and in a red and . a',
#  'a brown dog runs on brown grass .|a brown dog is in a and .',
#  'two children wearing orange walk across a long pier .|a people are a and on a red . .',
#  'a large brown dog is digging in the sand .|a dog dog dog is running on the grass .',
#  'three dogs race towards the viewer over a lawn .|a dogs are in a water . a ball .',
#  'two dogs romp through a meadow of high grasses|a dogs are <pad> the ball . a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man plays a bagpipe while another checks on the instrument .|a man in in man of a man in a air of',
#  'the black dog is running through the water on the beach .|a black dog is running in a water . a beach .',
#  'people are riding in a boat with oars .|a are playing a a blue . a .',
#  'a man rides large waves on a wind sail .|a man is a the in a water . .',
#  'a black dog runs across the dirt road .|a man and is on a beach . .',
#  'a dog stands shoulder deep in muddy water .|a white is in in . the . .',
#  'a woman in a string bathing suit with a man on a boardwalk on a foggy day .|a man with a red shirt is a a black is a red . a large . .',
#  'two soccer teams are playing <unk> one is in white the other in red .|a men are are playing in and in running a and air . a and',
#  'a woman wearing an orange jacket sitting in a canoe on a lake with a dog behind her|a boy is a orange and is on a red . a bike . a white . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a girl laying on the tree with a boy kneeling before her .|a man is on a air . a man in . . .',
#  'adults and children stand outside of open barn .|a in man are on a a . .',
#  'a boy holding an oar walk through the ocean .|a boy is a orange and in the water .',
#  'a white car racing in the dirt and water|a person is is on a air . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'three children jumping into a pool with a palm tree in the middle .|a young are in a blue . a green in . the water .',
#  'a man reads quietly alone in room .|a man is a a in a .',
#  'the young man dives on the field during a sporting event .|a boy boy in a a air . a ball . .',
#  'a brown and black dog approaching a red ball .|a dog dog white dog is a dog and in',
#  'three boys are struggling with one another and reaching for bag of litter .|a children are playing in a man in white in a . a .',
#  'girls cartwheeling inside .|a in in a',
#  'a child flying a kite .|a young is in red in',
#  'black dog jumps through snowy field .|a dog is a the . .',
#  'four people walk on a bridge over a body of water .|a people are on the skateboard of a white . a .',
#  'two girls hugging .|a children in on',
#  'little kids play in the water while their friend poses on top of their raft .|a boy in on a water . a in on . the of a . .',
#  'a large van drives down a counry road in the fall .|a man dog is and a red . . a air .',
#  'the head coach is walking out on the field .|a man is in sitting in a the snow .',
#  'a boy wearing a flowered shirt raises his arm and jumps .|a girl in a red and is a a . a .',
#  'a group of people are in the water .|a man of people are playing the snow .',
#  'three teens watching a basketball in the air .|a people people a man of a air .',
#  'a young boy jumping into a pool .|a woman boy is in a ball .',
#  'boy jumping off skateboard as it goes down the stairs .|a in on a on a . . a grass .',
#  'a man holds a fish in both hands .|a man is a red . a a .',
#  'two asian girls dressed in black pose for a picture in front of dry trees .|a girls girls are in a and . a large . a of a . .',
#  'a man works on his garden .|a man in a a bike .',
#  'man and dog standing on the beach .|a in a in on a grass .',
#  'two long haired dogs racing down a forest path .|a dogs dogs dogs are on a grassy . .',
#  'a soccer player in a white shirt kicked a goal .|a young in in a red shirt and a black .',
#  'a group of older people are sitting outside under their marine-life-themed umbrella .|a woman of people are are on in on a . . .',
#  'a woman in a green shirt and blue hat is playing tennis .|a boy in a red shirt is white shirt is running a .',
#  'a black puppy standing inside beside an orange .|a black dog dog in a a orange .',
#  'the person in the red and black uniform has a ball above her head .|a young in a blue shirt white and and a white in a . .',
#  'two brown and black dogs run through the dry grass .|a dogs dogs white dog are through the grass . .',
#  'two women <unk> one looking down <unk> the other drinking .|a people are and in at a and street . .',
#  'the yellow dog is carrying a stick by water .|a dog dog is running a white in a .',
#  'a young child is running through a large puddle at a beach surrounded by trees .|a little girl in on on the ball ball . a ball . . . .',
#  'a man on an escalator carrying a red and white cup looking up .|a man and a orange . a man shirt white dog . . .',
#  'a man in a red shirt is jumping from one rock to another larger rocker with two male spotters below him .|a man is a blue shirt and standing on a on . a a . . a the . . . .',
#  'a person riding a horse with a mountain range in the far background .|a man is a black . a large . . the air . .',
#  'three young people pose by a snowman in a red tie .|a people people are in a man in a red and .',
#  'two little girls <unk> wearing pink hanging on a tube .|a children boy in a a and on a rock .',
#  'two men walking past a graffited wall scene of a red classic car|a men are in a man . .',
#  'four people are in silhouette whilst watching the sunset .|a people are playing a of a a grass .',
#  'a dog chases a white animal on a green lawn .|a dog is a brown dog in a ball . .',
#  'a person is wading through a river near an eroded embankment .|a man in running on a water in a orange . .',
#  'woman on grass <unk> <unk> small dog as another dog jumps up .|a in a in a white a with a dog . in .',
#  'a skier rapidly descending a steep snow covered hill .|a man is on on mountain . . . .',
#  'a person wearing a white shirt and blue shorts with cables attached to him .|a man in a blue shirt is a shirt is a of on a a',
#  'a group of people sitting at a sporting event .|a man of people are on a man . .',
#  'two men taking a picture together with the phone of one of the men|a people are a man . . a camera . a and a of . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young boy practices his bat swing while in the stands with blue seats .|a woman boy is a a . a a the air . a shirt .',
#  'a woman holds a baby while a man looks at it as another man holding a child watches .|a man in a man in a man in a a . a . in a blue in .',
#  'two kids playing on the beach <unk> close to the water|a children are in a grass . a . a beach . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a black dog is running along the beach beside a brown dog in midair catching a stick in its mouth .|a dog dog is running in a water . the field dog . the . . ball . the mouth .',
#  'a man in a full wetsuit surfs a crashing wave .|a man is a blue of is on ball . .',
#  'a surfer vertical in a wave with another approaching him|a man is a the field . a in . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'the brown dog is standing on the beach as the waves lap up around its feet .|a brown dog is running in a water . a water . . a in . .',
#  'a man in a white outfit on a bench|a man is a red shirt and a blue . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'three women sit on the subway ; one talks on the phone while the others read .|a people in in a air . . . . a street . a street of .',
#  'a brown dog digs in the sand happily .|a dog dog is a a grass . .',
#  'the man is standing in the river next to smoking grass .|a man in running in the water of to a . .',
#  'a swimmer is doing the backstroke in the swimming pool .|a little is jumping a water in the water . .',
#  'two elderly females sitting on a white bench amongst trees .|a people girls are on a man . . . .',
#  'a boy plays with a water tube .|a woman in in a man . .',
#  'a child in red sits in the snow .|a little is a shirt is a air .',
#  'a man windsurfs in the ocean .|a man is on the air .',
#  'the bike rider is wearing a silver helmet and red shirt .|a man is in standing a blue is a a shirt .',
#  'a black dog leaps through the snow near a fence .|a dog dog is in the snow . a large .',
#  'a motocross bike is jumping through the air between two lines of red tape .|a person is is standing a a air . a of . a . .',
#  'several people in a park walking on a low wooden boardwalk .|a people are a red and on a . . . .',
#  'a baby wearing green holds onto plants and puts them in its mouth .|a young in a a a a a white with . the mouth .',
#  'a man in a knit cap stands next to a brick wall .|a man in a red shirt and . to a red . .',
#  'a black insect approaches a flower .|a man dog in a large .',
#  'three uno cards in reds and yellows in the foreground <unk> with a young boy holding <unk> cards in the background .|a boy girls in a . a . a air . a a red girl in a a . the background .',
#  'a little girl is smiling <unk> while running outside .|a girl boy is running in a a on .',
#  'a tan dog climbing over a bare tree trunk with a man standing in the background|a man man is a a rock of . . a large in in the snow . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man jumps off a hill .|a man in on a blue .',
#  'dog yawns|a is in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man wearing a pirate hat and eyepatch smiles at the camera .|a man in a blue shirt is a . on a street .',
#  'a close-up of a man shooting a handgun into the woods .|a man man a man is a blue on a air .',
#  'three black dogs play in the glass .|a dogs dogs are in the snow .',
#  'little boy in yellow shirt is climbing out of a plastic playground tunnel .|a girl in a shirt and standing a a a man . . .',
#  'an asian girl is smiling whilst standing in font of some green bushes .|a woman girl in standing on in in the . a . . .',
#  'two black dogs and one brown dog in tall grass .|a dogs dogs are white dog dog running the in .',
#  'a man in a hardhat stands beside a ladder .|a man in a red shirt in a red .',
#  'a lean dog runs through green grass .|a dog dog is through the grass .',
#  'people mill about a large are with a round desk .|a are a on man . in a man . .',
#  'a young boy is twisting a sparkler around in the air .|a man man in on in bike . a the water .',
#  'three people standing near a door <unk> with silly string cans .|a people are in a red . in a . . .',
#  'two dogs running through tall grass .|a brown are in a . .',
#  'two people are on top of a cannon .|a people are on a of a rock .',
#  'the skateboard is falling away from the skateboarder as he attempt a jump .|a man is jumping a on a air . a . . skateboard .',
#  'goal attempt during a soccer game being played on green grass .|a people in a red in . . . a grass .',
#  'a boy in a green t-shirt is riding on a segway|a girl is a red shirt is playing a a skateboard . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a mountain biker is riding along a heavy dirt trail in a wooded area .|a man is a riding a a blue . . . the blue . .',
#  'man helps another person reach the top of a rock they are climbing .|a in a in in in water of a red . . . a',
#  'a man climbing a cliff .|a person in a blue in',
#  'two bums are sitting on a sidewalk outside a peace mission in portland oregon .|a people are playing on a large . . white . . a . .',
#  'a man looking at the camera with another man wearing a mask .|a man in on a camera . a man in a red .',
#  'a man next to a plastic crate and a bicycle <unk> writes on a board .|a man in to a red and . a man . in a a crowd .',
#  'a small dog laying on a stuffed animal in front of a tv|a brown dog is a a ball . . a of a field . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a little girl walks on a boardwalk with blue domes in the background .|a boy girl in in a ball . a and . the snow .',
#  'a man stands next to a car .|a man in in to a ball .',
#  'a small boy dressed in a black sweatshirt with a logo on it <unk> holds a red bat in front of blue stadium seats .|a child boy in in a white and and a red and a . . a white shirt . a of a . . .',
#  'a kangaroo wearing a yellow and black striped vest with the number eight on it is hopping .|a man in a black shirt white and and is a white is . the . . .',
#  'dog with black and tan face standing in water looking up at camera .|a is a and white dog is in the . . . the .',
#  'a man and a woman are posing for a photograph in front of a yellow flower-bed .|a man in a man in playing a a man . the of a red . .',
#  'a kayaker is battling waves in a purple boat while wearing rain gear .|a man is jumping on on the blue of . a a . .',
#  'brown <unk> black and white dog standing on a sandy slope .|a dog and and white dog is on a field . .',
#  'two dogs run towards each other on a rocky area with water in the background .|a dogs are through a of . a field . . a . the snow .',
#  'young boy dressed in green holds baby goat in arms .|a boy in in a shirt a and . a .',
#  'two men are playing basketball and one is trying to block the others shot .|a men are playing in in a of running to a a water . .',
#  'football players playing in mud .|a people are on the .',
#  'a white dog in the snow carries a plastic mountain dew bottle in its mouth .|a dog dog is a grass . a beach . . . . the mouth .',
#  'a young boy is playing in leaves .|a woman girl is running on the a',
#  'a man is sitting in room made up of wood panelling .|a man in jumping on a a . a a . .',
#  'the football player runs with the ball across the field .|a man people in a a camera . a grass .',
#  'a girl in striped swimsuit is jumping into the ocean .|a girl is a is in standing a a water .',
#  'there is a man sitting in a restaurant at night .|a people sitting man in on a blue . a .',
#  'guy in santa suit wearing ninja mask and horns|a in a and . a in . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog jumps over a barrier .|a dog is a a ball .',
#  'three shirtless boys are playing in the water .|a young are in playing in the air .',
#  'a young girl is sliding down a snow slope in a red sled .|a girl boy in sitting a a red . . the red . .',
#  'a snowboarder wearing a black and white striped jacket is kicking up some snow .|a man in a red and white shirt and in standing a a . .',
#  'a person wearing a white hooded sweatshirt covered with a blanket sitting on a bench reading|a man in a blue shirt and a on a red and on a red . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'one black dog running with a ball and small tire in his mouth while another black dog follows .|a black dog is on a black . a dog . a mouth . a dog dog in .',
#  'a person wearing a helmet begins to fall from a silver scooter .|a man in a red and a a . a red . .',
#  'a bald <unk> shirtless man rock climbing .|a man man is in in a a',
#  'brown and white dog runs towards camera <unk> casting long shadow on dirt .|a dogs white dog is through the a . a . . the .',
#  'two children are sitting in some tree branches .|a men are playing on the . . .',
#  'some children turned backwards while in the audience .|a people are in in a a air .',
#  'a man raises a campaign sign over his head .|a man in a red in . a mouth .',
#  'a beige dog runs through the shrubbery toward the camera .|a brown dog is in the water . . grass .',
#  'a person in hiking gear is standing on a hill with a mountain in the background .|a man is a is on on on a beach . a ball . the air .',
#  'people look out the window at mountains .|a are in a camera of a .',
#  'a small girl wearing a white and multi-print dress sitting at the bottom of a slide .|a girl girl in a red shirt white . is on a camera . a red .',
#  'a young blond girl standing in front of a large fenced in fountain|a young boy girl is in the of a blue . . front . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a woman in a pink striped shirt <unk> with her hand up .|a man in a red and and and and a and in a',
#  'a german shepherd is running with a stick in its mouth .|a dog dog dog running through a dog in the mouth .',
#  'a boy wearing a white hat is running on the beach .|a man in a blue and is running on a beach .',
#  'the two football players in white jerseys and purple pants tackle the player in the red jersey .|a man children are are a and . white in . a street . the water . .',
#  'a man on rollerblades grinds a wall .|a man in a . in large .',
#  'girl in black pants and an orange top jumping with one leg outstreached and foot pointed other in background dressed the same .|a in a and and a orange and of in a and . . a . . . the . . . .',
#  'a young asian girl stands between two tree trunks .|a little boy girl in in a of . .',
#  'a man in a yellow shirt wears a gold <unk> <unk> mask .|a man in a blue shirt is a red and and and .',
#  'a man in a blue jacket lifts a child dressed in red out boat crowded with people|a man in a blue shirt and a black in in a and . . . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man in a green hat standing on a slope in front of a mountain .|a person is a blue shirt on in a a . the of a large .',
#  'the dogs play on the snow .|a brown in in the snow .',
#  'a tan dog swimming in some water|a man dog is in the water . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young man parasailing in the ocean .|a man boy is a the air .',
#  'a small white dog is jumping over a green and red obstacle bar .|a white dog dog is running in a ball ball white . . .',
#  'two girls in swimsuits are playing in the water near the seashore .|a people in a a running in the water . the water .',
#  'a small black dog runs through the white snow .|a black dog dog is through the snow . .',
#  'guys gathered outside an ice cream store on a sunny day .|a people in in orange . . . a city . .',
#  'two dogs are looking up at a person .|a dogs are playing at in a large .',
#  'an irish dancer performs a solo .|a man of in a large in',
#  'a man wearing no shirt does a trick on his red and black bicycle .|a man in a is on a red on a bike . a and .',
#  'a little girl with a bow in her hair <unk> doing a <unk> on the grass .|a young girl in a white in a and is a a ball and a grass .',
#  'three kids play with silly string .|a people are in a in .',
#  'a motorcyclist navigates a forest trail .|a man is on blue is .',
#  'man sitting with headphones at a laptop .|a in on a a a building .',
#  'four people and the sun .|a people are a man are',
#  'a black and brown dog running in a field|a dog dog white dog is on a field . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'two dogs <unk> one lying down <unk> play in a yard .|a dogs are on dog in a in in the field .',
#  'the matador is struck by a charging bull as he stabs it with his swords .|a man is jumping in a large . . a . a . a mouth .',
#  'a young girl in a pink room tries to play a black electric guitar .|a woman girl in a blue shirt and is a . blue . . .',
#  'two dogs are playing together|a dogs are running on in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a woman in a salon gets her hair colored and permed|a man in a red shirt a . . . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'two basketball players oppose each other at the net .|a men are in in other . the grass .',
#  'a climber approaches the top of a cliff high above the surrounding terrain .|a man is a of of a rock . . a water . .',
#  'three boys climb on a slide|a people are a a red . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man parasails in the waves <unk>|a man is a the water . a <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a boy does a skateboard jump at a skateboard park .|a man is a man is . a red . .',
#  'a man stands at the peak of a mountain and has his hand on a monument .|a man in on a water . a beach . a a . . a red .',
#  'a street market filled with white tents <unk> pedestrians <unk> and <unk> .|people man of people a a and are and . a a one',
#  'a girl with bright red hair and black clothes is posing on a tree trunk .|a woman in a and is and a and and running a a red . .',
#  'the girl is at a petting zoo and feeding a camel .|a girl is sitting a red . . a . ball .',
#  'two black dogs splash through the waves on a beach .|a dogs dogs are on the water of the beach .',
#  'two parents and a young girl blow up a raft .|a girls are a woman girl in on a red .',
#  'a skier in a ski suit is skiing downhill <unk> near a fence .|a man is a red is . jumping . a a a ball .',
#  'two men dressed jackets and hats are standing on a terrace|a people are in in a in standing on a man . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a small brown and white dog lines on a red area rug in a patch of sunlight .|a man boy and white dog is a a green . . . the field . a .',
#  'a woman searching for cans in the trash to put in her grocery cart .|a man in in a a a snow . a . a . . .',
#  'two black dogs running in snow with toys in their mouths .|a dogs dogs in in the . a in the . .',
#  'there are 5 brown dogs on leashes with their owners nearby .|a dogs playing in dog in the . a . . .',
#  'people under a tent .|a are a man of',
#  'a man in a yellow sweatshirt and black pants plays with a black poodle .|a man in a blue shirt and white and is on a black dog .',
#  'woman in blue shirt blowing very large bubble|a in a shirt and in a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a small child wearing a pink hat <unk> bluejeans <unk> and white shirt standing in a grass field .|a little boy in a red shirt is blue in a a and is in the red . .',
#  'a young boy in a red football jersey makes a large gesture as he stands in the midst of pumpkins .|a man boy in a red shirt is in a red . . a . . the air',
#  'pedestrians walk in front of an advertisement depicting a shirtless man in jeans .|a in in a of a . . . red . in a .',
#  'the large <unk> dark colored dog is doing a climbing stunt outdoors <unk> while a man watches .|a black dog brown and dog is running a red . . . a a dog in .',
#  'two bikers race uphill .|a men on on on',
#  'a black dog jumps in the air over the red hurdle .|a black dog is in a air . a grass of .',
#  "a bullfighter skewers his prey just as he 's hit by the bull .|a man dog is a a in a on in . a grass .",
#  'a dog is on the bed holding a toy soccer ball .|a brown is running a beach . a dog . . .',
#  'two people in shorts hike on the snow in the mountains with a lake in the background .|a people are a in on the beach . the snow . a large . the snow .',
#  'a boy holding a float .|a girl in a man in',
#  'a black dog running a course at a dog show|a black dog is on ball . a ball . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'the rugby players in red are wrestling the player in yellow to the ground .|a young player in the and playing in water in the . a air .',
#  'two young children on a skateboard going across a sidewalk|a girls people are a man . . a ball . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'the lady wearing a black hat is taking a picture while the snow falls .|a man is a red and is standing a red . a camera . .',
#  'a man on horseback on a grassy field in front of mountains .|a man is a in a red field . the of a .',
#  'a brown dog runs in the woods with a serious look on its face .|a dog dog is in the air . a grassy . . a mouth .',
#  'a blonde woman with a red backpack in the snow .|a man is in a red shirt in a air .',
#  'two dogs chase each other across the snowy ground .|a dogs are in other . the water . .',
#  'two young boys swimming in a pool of green water .|a children girls are in the pool . a water .',
#  'the boy in glasses is reading .|a man in a and sitting a',
#  'a man and a skateboard on top of a barrel .|a man in a man in a of a red .',
#  'a dog leaps for a toy on a road .|a boy is a a large . the field .',
#  'a black dog is running quickly along the ground .|a dog dog is running on in a grass .',
#  'two white dogs are playing with a brown dog and a ball .|a dogs dogs are running in a ball dog in a white .',
#  'a motocross bike is being ridden along a woodland path .|a man is in jumping on on a red . .',
#  'women participate in a skit onstage .|a are in a red and .',
#  'four boys mug for the camera in front of a brick wall .|a children in a a street . a of a man . .',
#  'a bearded man in jeans and a black shirt riding a bicycle in the street .|a man is is a is a white and is a bike in a air .',
#  'two dogs playing with the same red toy .|a dogs are in a air . . .',
#  'a race car drives through a dirt-covered racetrack .|a man and on a a grassy . .',
#  'a teenage boy on a bicycle does tricks .|a man man on a red on a .',
#  'a black standard poodle running through the snow in a fenced-in yard .|a black dog dog dog through the water . a field . .',
#  'two women <unk> the younger one is looking down <unk> the older is drinking .|a men are a man in is standing at a a camera . in in',
#  'three children play in a water park .|a people are in the red . .',
#  'a black and white dog with a blue toy in its mouth runs on a grassy surface just beyond a fence .|a black dog white dog is a black dog in a mouth . . a pool field . . . ball .',
#  'a brown dog jumps high in the grass .|a dog dog is a in the snow .',
#  'three black dogs running after an orange ball .|a dogs dogs are in a orange . .',
#  'a woman and a boy on a unicycle .|a boy in a man in a blue .',
#  'a march to protest the construction of a coal power plant .|a man in a on man of a man in . a',
#  'small boy holding is arm out to balance himself while he goes down the fairground slide .|a little in a on a a a . . a . a a beach . .',
#  'someone with a wave rolling over them .|a in a red . . a .',
#  'three members of the red team are in the grass with a member of the yellow team .|a young are a man and in playing the water . a red in a water . .',
#  'a girl with her leg out on a lawn .|a man is a is on of a beach .',
#  'a big <unk> brown dog is shaking off while in the water .|a dog dog brown dog is running in a a the water .',
#  'a woman brushes dust and dirt off a possible find .|a man is a on a in . blue . .',
#  'two people rafting down a river near pine trees .|a people are in a field . a . .',
#  'two boys are playing flag football .|a people in playing on in .',
#  'a young girl with braids is painting with water colors on a white paper on the wall .|a boy girl in a boy playing a a and in a red . . a snow .',
#  'a man in shorts skis down a hill .|a man is a on in a red .',
#  'a collie jumps over a hurdle .|a black is and a red .',
#  'the woman is wearing black shorts at a parade .|a boy wearing standing a and is a red .',
#  'two boys are squirting water guns at each other .|a people are standing a . . a . .',
#  'a large tan dog jumps in the air over the grass in a fenced yard .|a dog dog dog is on the grass . a grass . a field . .',
#  'a boy in a striped oxford shirt points .|a young in a blue shirt . is a',
#  'man in uniform stands near woman with purple hair .|a in a is in a in a and and',
#  'a skier is falling into the snow .|a man is on a a snow .',
#  'a boy and a girl are dressed in colorful costumes .|a woman in a man is on in a',
#  'two white dogs are playing in the snow .|a dogs dog are running in the snow .',
#  'a man playing rugby has the ball and tries to evade a tackler .|a man in in a a beach . a . a . dog .',
#  'a person climbing a large moss-covered rock|a man is a blue ball a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a woman and children with their ice cream cones .|a woman in a in a and . and .',
#  'a large brown dog is crouching in a grassy field .|a dog dog dog is running a a black field .',
#  'two people row a boat past rocks in water .|a people are in red . . . the .',
#  'two men are sitting at a table outside a coffee shop .|a people are playing on a table . . mountain . .',
#  'a blond dog runs down a path next to a rhododendron .|a dog dog is through a ball . to a white .',
#  'a young boy jumps into water .|a man boy in on a .',
#  'this dog is running through water on a beach .|a black is running in the . the stick .',
#  'two large dogs lying on their backs on a purple comforter .|a dogs dogs are in a . . a ball . .',
#  'a golden retriever has on a collar and a harness and has a muddy lower body .|a brown dog dog a a white dog white brown . white dog white . . .',
#  'a young girl wearing a tutu dances in a large room .|a girl boy in a blue is . a red . .',
#  'seven jockeys riding horses in a race .|a people are a on the field .',
#  'two people are standing in shallow water <unk> waving sparklers around|a people are playing on a of . . a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a woman sites with her feet on the seats in a subway car .|a man in a a and and a street . front black . .',
#  'black dog jumping over a white dog in a snowy path .|a and is in a red . . the field . .',
#  'a lot of men and motorcycles float on a canoe .|a man of people in a in a a street .',
#  'a girl with her hair flying up from her head poses on a skateboard|a boy in a and in on a a . . . a field . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a crowd watching a dirt bike race|a man of a man of . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a crowd walks along a sidewalk of a farmers market .|a man of in a large',
#  'two opposing male players are chasing the ball in field hockey .|a men are in in in the grass . the . .',
#  'a man standing on a concrete platform with his arms wide open|a man is on a red . . a . . . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'the woman is holding a baby girl wearing a striped dress .|a woman in wearing a red and in a red shirt is',
#  'people sit against a wall|a in in a blue . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a curly-haired boy jumps up on a bed .|a boy is in a a a ball .',
#  'a group of skiers shown on a snow covered mountain .|a black of people is and a black . . .',
#  'a man prepares to interact with a lock for a bicycle while staring away from it .|a man in on a a a red of a bike . a . . a .',
#  'a mother is holding her child on a train .|a man in standing a a in a bench .',
#  'a baby crawls next to a street against a blue sky .|a girl girl in to a man . . red . .',
#  'two children on the beach .|a children in the water .',
#  'a child in a red shirt plays with fireworks .|a young is a red shirt and in a .',
#  'a snowboarder in stripes .|a man in a a',
#  'a man in a red shirt at the top of a set of stairs with arena lights on in the background|a man in a red shirt is a camera of a large . a . a . . a the grass . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'two german sheperds snarling at each other .|a dogs dogs are in the other in',
#  'a kid wearing safety gear stands on some material in the water .|a man is a shirt is on a . . the water .',
#  'the little boy in jean shorts kicks the soccer ball .|a man girl in a is and to grass . .',
#  'window shades cast light and shadow on a dog lying on a colorful carpet .|a in in a . a . the skateboard . . a skateboard . .',
#  'a dog chasing an animals tail on the grass .|a dog is a orange in . a grass .',
#  'a basketball player is jumping and about to dunk a ball in front of a crowd .|a man player in in in a to a a ball . the of a man .',
#  'four young men are running on a street and jumping for joy .|a men men in playing in a red . a . a .',
#  'a baby in a white and pink dress walks outside .|a young girl a red shirt white shirt is in .',
#  'a black dog swimming in water near rocks .|a black dog is in the . a .',
#  'the dog runs in the park .|a man is through a air .',
#  'a little boy in a swimming pool .|a man girl in a red shirt is',
#  'a sled dog team running from the perspective of the rider .|a man is is in in a snow . a snow .',
#  'two young asian girls stand in the street and look concerned .|a girls girls girls are . a air . a . a',
#  'two women sit on a city train .|a men in in a man . .',
#  'a motorbike jumping a pole .|a man is on man .',
#  'a dark dog is in a body of water .|a dog dog is running the red of a .',
#  'a white and brown dog is catching a red ball in its mouth .|a dog dog white dog is running a large ball in a mouth .',
#  'a man is sliding down a huge sand dune on a sunny day .|a man is jumping a a large . . . a beach . .',
#  'the boy in the green and yellow shirt has a glove on and is going towards the ball .|a man in a field ball white and and a black in a white in . a water .',
#  'a warmly dressed girl kicks up her leg outdoors .|a man girl in in in in to . .',
#  'a brown and black puppy stands by a camera .|a black dog white and is in a red .',
#  'someone is holding up a green fish for display outdoors .|a in on a a red . . a . .',
#  'four people <unk> in colorful kayaks <unk> are on the water on a sunny day .|a people are in a and a a standing a water . a blue . .',
#  'two people stand on the top of a snow covered mountain .|a people in in a air of a red . . .',
#  'a group of people are sitting around a table under a blue sunshade .|a woman of people are in on a woman . a bench . .',
#  'two racing dogs run in the mud .|a dogs dogs are on the air .',
#  'a softball player swinging at a softball and missing it .|a man and in a a ball . a a .',
#  'a man climbing a rock cliff .|a man is a red . .',
#  'a skateboarder jumps on brick stairs .|a man is on a . .',
#  'a young girl jumping out of the water at a pool|a girl girl in in the a water . the tree . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'someone hikes through a snowy mountain range|a in a the snowy of . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'speedskater skating a race .|a young in boy in',
#  'a wrestler is falling onto another wrestler who is laying in a ring .|a man in sitting a a man in in standing on the blue .',
#  'the blond haired girl wearing the flowered dress is swinging on a swing towards the blue sky .|a young girl girl in a air . . standing on a large . . street . .',
#  'a small dog stands next to a larger dog <unk> out in a field .|a brown dog is in to a dog dog . a a the field .',
#  'a man in red holds up a cellphone on the sidelines of football game .|a man in a shirt a a red . a beach . a . .',
#  'a little kid holding a yellow and red soccer toy .|a little girl in a red shirt white shirt . .',
#  'the dogs are joined together with a red harness .|a dogs playing playing in in a dog and .',
#  'a dog is jumping through the air in an open <unk> snow covered field .|a dog is running on the beach . the . . and . . .',
#  'a child in a white and orange outfit doing push ups .|a little is a white shirt white shirt and a in .',
#  'a black and white dog is walking on a beach .|a black dog white dog is running on a grassy .',
#  'painting of albert einstein on a bear with child reaching up .|a people people are on a red . a in . .',
#  'a sled-dog team works hard on this snowy trail .|a man of in a in a . . .',
#  'two dogs are shaking water off .|a dogs are running in . .',
#  'smilling and laughing baby in a walker with fire engine airplane mobile and other toys on the floor|a little a in in a blue . a . . . . a . . a grass . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'horses jumping a hurdle in a race .|a are in man . a street .',
#  'a boy in an orange shirt and red hat is standing next to a girl with a white shirt and blue pants in the sand next to the ocean .|a man in a orange shirt is white and is walking in to a beach in a red shirt is a and is the air . to a grass .',
#  'a young girl hula dances in front of a colorful backdrop .|a man man in in a a of a red . .',
#  'two brown and white dogs are standing on a sidewalk .|a dogs dogs white dog are in in a beach .',
#  'a small dog chasing after a bucking cow|a dog dog is a in white . a <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'brown dog splashing into the water .|a dog is in the water .',
#  'two football players are getting ready to tackle each other|a people player are playing are',
#  'a small dog is standing behind a camera .|a black dog is running on a red .',
#  'a woman in a white dress walks toward the water on a beach with white boots in the foreground .|a girl in a red shirt is in a water . a beach . a . . a air .',
#  'young girl in ponytail pets furry cat|a girl in a a and and in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'two men with backpacks placed in front of them sitting in front of a railing .|a people are a are on the of a . on the of a building .',
#  'the brown dog is in the waving water .|a dog dog is running the water water .',
#  'a man wears a floral bathroom as he stands over a trashcan .|a woman in a red and . a and in a red .',
#  'the woman in glasses is smiling with the ocean in the background|a girl in a is is on a water . the air . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a skier stands on his hands in the snow in front of a movie camera .|a man is in a bike . a snow . the of a mountain . .',
#  'a little toddler in blue pants is crawling on the road .|a boy boy boy a and is sitting a a beach .',
#  'a snowboarder in midair <unk> after jumping a ramp .|a man is a . a a on red .',
#  'a couple pose on their wedding day .|a man in in a of . .',
#  'sillhouttes of people in front of a mountain and in front of a window .|a people people are a of a red . a a of a large .',
#  "a young boy in a blue shirt and cap is jumping into a man 's arms .|a man girl is a red shirt and a and standing on a red in . .",
#  'two boys play with two dogs next to the ocean .|two dogs are in a dogs are to the water .',
#  'a brown dog holding a huge stick in its mouth running in the snow .|a brown dog is a blue in in the mouth . . the air .',
#  'a group of children are in a water fountain .|a man of people in in a black shirt .',
#  'a girl in a red polka dot dress and red headband playing with a pink handheld game|a man in a red shirt and and and a of and with a red . . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a dog swimming in a pond .|a man is in a field',
#  'a medium sized brown dog is running through an open white wooded area .|a dog dog dog dog in running in the orange . . . .',
#  'a baby in pink <unk> striped clothing is sitting near an older lady wearing red and black .|a young in a shirt is and in running on a . . . a and white .',
#  'a man with an electric guitar smokes a cigarette sitting outside .|a man in a orange and on . ball . . .',
#  'the lady has a tattoo .|a man in a girl and',
#  'a girl flies through the air as a man stands with his arms outstretched .|a girl in on a street . a crowd in in a in . .',
#  'a soccer ball is above the head of a man wearing black shorts and red and black striped shirt .|a man player in playing a snow . a white and a and . a and white and and is',
#  'two men in midair fighting in a professional wrestling ring .|a people are a is on the blue . . .',
#  'two men look out as one is holding binoculars .|a men are are a a in standing a .',
#  'a man pushing a baby stroller at the beach <unk> a woman with a little boy ahead .|a man in a blue in on a street . . man in a red girl is .',
#  'man is diving onto his wakeboard .|a in jumping on a on .',
#  'a golden retriever splashes in the water .|a brown dog dog in the snow .',
#  'a young laughing girl and a boy are playing on a big drum .|a little boy girl in a red in on in a field . .',
#  'a man and a boy wrestle inside a house .|a man in a man in a a red with',
#  'a dog is playing fetch with a ball .|a dog is running in in a black in',
#  'a man with blue boxing gloves is throwing punches .|a man in a shirt and . standing a .',
#  'a tan animal is being swatted in the face by a brown and white bull .|a dog dog in jumping a in a grass . a ball dog white dog in',
#  'a brown chow mix dog is standing in front of a van with euro plats in the middle of a messy yard .|a brown dog dog dog in running on the of a red . a . . the grass . a field . .',
#  'three boys in size order getting wet next to a wall|a people in a is in a in to a white . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a black dog nurses white puppies .|a black dog is a and .',
#  'a woman screams as a man throws a deck of cards .|a man in a a woman in a red . a .',
#  'the kid is playing hopscotch .|a man is standing in on',
#  'children and adults play with a sprinkler .|a are a are in a white .',
#  'a young boy in a blue jacket pulls something black out of a fabric bag .|a man man is a red shirt is a . . . a white . .',
#  'two boys <unk> surrounded by paper pieces <unk> hold a third boys shirt to prevent him from grabbing a bag .|a children are playing in a in in a in white . . . a . . the . ball .',
#  'a man reaches toward dunking a basketball while an audience watches .|a man is on a in woman . a orange . .',
#  'a man stands on a four-wheeled board attached to a harness .|a man wearing on a red . . . a ball .',
#  'a little boy puts a bat on his forehead and spins around .|a young boy in a blue in a mouth . a . a',
#  'a woman in semi-formal attire is sitting on a concrete wall .|a girl in a is a sitting on a black . .',
#  'a very little child swings on a tire swing .|a man black girl is in a beach . .',
#  'a man is clapping at the base of the washington memorial .|a man is playing a a air of a water . a',
#  'the obama supporter wears a black jacket and brown hat .|a man is a a woman shirt . a and is',
#  'a brown horse jumps through its paddock .|a dog dog in in the mouth .',
#  'an artist paints clouds onto a canvas .|a young boy in on a red .',
#  'a cow herd grazing in the pasture with a dog running in the foreground .|a man dog in in the snow . a black . . the air .',
#  'a man wearing a blue shirt crouches on a rocky cliff .|a man in a red shirt is on a rock . .',
# ...
#  'a woman taking pictures of the surf and a child in the foreground .|a man in a in a woman of a woman in a water .',
#  'a boy gets flipped into the river by another boy .|two man in a in the water in a of in',
#  'a man in green kick a soccer ball while a man in purple and white is falling down .|a young in a a and red and in a brown in a and a and is a a',
#  'man wearing boys will do boys shirt waves at camera during gay pride parade|a in a and . and . . . a . . . . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  "the black dog 's head is poking up out of the water .|a black dog is a . in a the of a water .",
#  'a blonde child riding a tire swing .|a little girl in a red in .',
#  'the woman is guiding a brown and white dog over a tall white fence on an obstacle course .|a man in jumping a green and white dog is a field in . . the . . .',
#  'a bird with a long orange bill drinks water .|a white is a white white and . . .',
#  'a racer on an atv leaves the ground in a jump .|a man is a orange . a air . front red .',
#  'black dog jumps from hay ball to hay ball .|a dog is a a a . a a .',
#  'a pale colored dog runs through a body of water .|a dog dog dog is through the black of a .',
#  'a man in a red striped soccer shirt heads a ball .|a young in a red shirt is and and . blue .',
#  'a trick cyclist takes air .|a man on a a .',
#  'a man without a shirt is walking on top of lots of rocks .|a man is a blue is jumping on a of a in a .',
#  'a man with a canoe is on the beach with a tent set up .|a man in a blue in standing a grass . a blue . . .',
#  'a black and tan dog is running along a series of stone walkways spaced between grass .|a man dog white dog is standing in a field . a . . . . .',
#  'a skateboarder goes down some stairs .|a man is a a . .',
#  'the long black shadow casts a image on the rock while the young girl climbs the rock .|a man man and in a man of a water . a street boy in . water .',
#  'two dogs play with one another outside .|a dogs are in a black dog .',
#  'a man stands at the top of a stadium staircase .|a man is on a beach of a red . .',
#  'several people shopping at an outdoors market .|a people are on a orange . .',
#  'a man wearing a cowboy hat and a gold cross around his neck|a man in a red and . a red shirt . a',
#  'people ride up an escalator .|a are a a a .',
#  'a man takes a picture of another two men in a crowd .|a man in a woman . a',
#  'shoppers in a fruit and vegetables market looking around .|a are a black of white a a at a',
#  'baby wearing red hat in car seat .|a in a shirt is a on a',
#  'a little boy in orange pitching at a baseball game .|a man girl is a shirt and a blue . .',
#  'several people work on a machine .|a men are a a street .',
#  'an asian boy and girl walking amongst a crowd with trees over their path .|a girl girls is a in in a white . a . a . .',
#  'a dog that is down in water is shaking off .|two dog is a running a the . running in .',
#  'women who look alike are performing on a stage .|a in in are in in',
#  'a motorcycle rider is slightly airborne on a motocross circuit|a man is in in a on a bicycle on . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a brown boat is packed with goods and people .|a man is in playing a a in a in',
#  'a group of men are changing the shells on a cannon .|a man of people are playing a street . a red .',
#  'a shoeless strapped in individual jumping with rubber bands attached is airborne .|a man in a a on . a on . . . .',
#  'a dog is bounding through tall grass .|a dog is running on a a .',
#  'a tall <unk> thin <unk> brunette girl wearing combat boots standing on a sidewalk .|a boy is in in and a in a . a on a ball .',
#  'a wide eyed guy in a blue jacket is holding a beer and standing next to a guy holding his nose .|a man woman with in a red shirt and standing a red . a in to a man . a',
#  'a miami basketball player .|a man in in in',
#  'skiiers on snow cappedhills|a in a in in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a man rows his boat below .|a man in a in on in',
#  'a woman wearing shorts is holding a tan dog while a white dog jumps up in front of her .|a white in a and standing a red dog in a small dog is in a a of a .',
#  'a man in a wetsuit and helmet in front of a red wall .|a man wearing a red is a is a of a white shirt .',
#  'girl wearing purple jacket rides a red snow sled .|a in a and on a red shirt . .',
#  'a little girl with mud on her face cries .|a young girl in a and a on . .',
#  'a woman in jeans and a woman in shorts are petting a baby kangaroo .|a man in a and white white and a and running a dog . .',
#  'a group of people painting the side of a building in an array of colors .|a man of people are in street of a street . a . . a .',
#  'man rowing a boat .|a in a man in',
#  'a person holding a frisbee just out of reach of a white dog on a rural road|a white in a white in . a a . a dog and . the ball . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'an animal is attempting to cross the river .|a man in running on a a water in',
#  'a girl bends down to paint something underneath her .|a woman in in a a . . . .',
#  'a woman read the paper and drinks from a coffee cup in front of an art gallery poster .|a woman is a man is a in a red . . a of a orange . . .',
#  'two men wearing hats are shown at the front of a crowd of people .|a men are a and playing in a camera of a man of a .',
#  'a person kayaking down a small waterfall .|a man is a a large of .',
#  'two people are walking along a long cannon on a tank .|a people on on on a bike . . a field .',
#  'a person descends a rope from a cliff into the ocean .|a man is a red in a mountain . the water .',
#  'a wet black dog shakes itself off .|a black black dog is a a a',
#  'people running a race and the guy in grey is in the lead .|a are in ball . a camera . a . holding the background .',
#  'a brown dog is running through a wooded area .|a dog dog is running through the field . .',
#  'a rollerblader skating inside a tube .|a man is a a man in',
#  'a man wearing a large backpack is sitting in the grass near a lake .|a man is a black of is sitting on a snow . a field .',
#  'dogs walking in the grassy field .|a and in the air . .',
#  'a girl swings a bat during a softball game .|a man in a red . a table . .',
#  'a boy and his bike leaps into the air .|a man in a bike on a a street .',
#  'black and white dog jumping up in the snow .|a dog white dog is a a a water .',
#  'a woman walking over a bridge with tall grass on either side of her .|a man is on a yellow of a in . a . . a .',
#  'children playing in a pool .|a dog in the water .',
#  'a sooners football player is tackling an opposing player .|two young is in in running in orange . in',
#  'a young boy jumping into a pool that says `` no diving `` .|a man boy in in a red . . . . . . .',
#  'a couple hurrying past an urban ice skating park .|a man is of on orange . . a .',
#  'a man and woman are sitting on concrete stairs .|a man in a is standing on a . .',
#  'the black dog and the brown dog appear to be wrestling .|a brown dog is a grass dog is a a a .',
#  'many people at a gathering .|a people are a white .',
#  'tourists pose for camera at night .|a men in a a a .',
#  'a man in a wetsuit is surfing on a green surfboard .|a man in the red in jumping in a water water .',
#  'a man with a black shirt that says `` genetic freak `` is sleeping on a bus .|a man in a man and is a a in a . . standing . a grassy .',
#  'a tan and black dog walks happily through a field .|a black dog dog dog is in a the ball .',
#  'a hiker is climbing up a snowy mountain .|a man is standing a a mountain . .',
#  'a man talks on a cellphone while holding an obama campaign sign .|a man wearing a a red . a a orange . . .',
#  'the little girl is playing with her shoes off .|a girl boy in sitting in a in . a',
#  'a diver midair against an urban background .|a man is is a orange . .',
#  'the person in the striped shirt is mountain climbing .|a man is a air shirt is walking on a',
#  'a man wearing a pink ribbon on his arm has been splattered with yellow paint .|a man in a red shirt . a . . a a . a . .',
#  'a race car drives on a track while several people watch from behind rope .|a man in on a a bike . a people are . a . .',
#  'a black and white dog playing in the snow together|a black dog white dog is in the snow . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'older gentleman in a red coat and black and white polka dot scarf .|a man man a red shirt shirt a and white and and and .',
#  'while holding tight to the ball <unk> the man in red socks is getting tackled .|a man a in a boy in a camera in a shirt . playing . .',
#  'man on a motorcycle performing a trick high in the air .|a is a red . a bike . . the grass .',
#  'people on the beach and a kite in the sky .|a are a grass . a man of the water .',
#  'a small brown dog is running across the grass wearing a purple and green coat .|a brown dog dog is running on a water . a field . white dog .',
#  'a little boy in a yellow jersey playing in a playgym .|a girl girl in a blue shirt is . a red .',
#  'white fluffy dog running in the dirt .|a dog dog is through the air .',
#  'two opposing soccer players run toward the ball while a goalies prepares a block .|a children are in are a in grass . a dog . . ball .',
#  'an older man in a blue hoodie is sitting down next to his bags .|a boy boy in a red shirt and standing on a to a of .',
#  'a man is kayaking down a waterfall .|a man is jumping on a red .',
#  'a man in wetsuit jumps towards a wet bride .|a man in a is a a red . .',
#  'a wet dog is shaking off water .|a dog dog is running in a .',
#  'peoople stand outside a building near a street .|a people in a man in a man .',
#  'a dog with mouth open to catch the red ball .|a black is a in and a a water and .',
#  'women are riding horses in an arena carrying the flags of canada and the united states .|a are playing a in a orange . a water . a . a of . .',
#  'a miniature dachshund has an apron on its back .|a dog dog dog a orange a a mouth .',
#  'a small boy in yellow rides a bike very fast on a brick road .|a man girl in a and a red of on . a street . .',
#  'three smiling children running indoors .|a young in in in .',
#  'a woman skiing down a snowy mountain with a brown dog on a lesh running with her|a man is in a dirt . . a ball and . a beach . . a . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'four boys pose for the camera .|a girls in in a air .',
#  'a dog zips along the beach .|a white in a a grass .',
#  'the fuzzy dog runs through the water .|a dog dog is in the grass .',
#  'a number of people standing and laying under a mountain covered in snow .|a man of people are in a of a mountain . . the .',
#  'a young boy wearing a red shirt hanging around a brown pole|a little boy in a blue shirt and on a red . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a small dog wearing a purple and green cape|a brown dog is a red dog white dog . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a bunch of people playing soccer .|a man of a are in in',
#  'children are practicing judo on red and white mats .|a in playing a on a . . . .',
#  'a matador in white and gold clothing and pink sock is getting hit by a raging bull|a dog is a shirt white is in a is on running a . a large . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a little girl in white leaves her boots behind as she walks in the sand .|a woman girl in a shirt on a a a a . . the air .',
#  'a woman is wearing a green striped shirt and a brown skirt .|a woman in wearing a red shirt and is a man and in',
#  'a black dog runs on green grass with its mouth open .|a dog and is on a grass . a mouth . .',
#  'a group stands on tan checkered tiles .|a man of in a a . a',
#  'two dogs playing on a beach .|a dogs are in the beach .',
#  'a brown dog with a tiny soccer ball in its mouth is standing on a blanket|a brown dog is a white is and in a mouth . running in the blue . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'children at a park .|a are a man .',
#  'a woman wearing purple and green is spinning a green hula hoop around her waist .|a man wearing a shirt white shirt jumping in blue . . . . . .',
#  'a boy in a white t-shirt is splashing in shallow water .|a little in a red shirt is standing in the . .',
#  'an asian boy in a red shirt holds onto an aqua balloon .|a woman man in a red shirt and a a orange . .',
#  'two men in blue jumpsuits <unk> one holding a bandaged girl|a men are a shirt and in and a red . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a young woman watches as a young blond boy swings in a chair swing with buildings visible in the background .|a man girl in a a red boy and in . a blue . . a . . the snow .',
#  'two dogs run across the grassy field .|a dogs are through a grass of .',
#  'a child in a red hoodie and black pants ice skating in a rink .|a man in a red shirt and a and in on a the red .',
#  'four boys posing for a picture with pumped fists|a children are in a black of a and . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'the girl is holding a blue balloon on a busy street .|a man in sitting a man shirt . a blue . .',
#  'a golden retriever is shaking off some water|a dog dog in running on a . . <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'toddler boy wearing airplane shirt <unk> in stroller with large beads .|a a in a a and and a a a . .',
#  'four kids holding hands jump into a swimming pool .|a people in a in on the ball . .',
#  'a woman dances along with a dancing video-game projected on large screen behind her .|a man in on a a white . . . a . . . .',
#  'a white dog is standing on a grassy hillside .|a white dog is running in a white field .',
#  'the people are showing their faces through frames .|a man are playing a . . the .',
#  'a man in green and black gets muddy on a dirt bike .|a man in a on a shirt is on a bike . .',
#  'a man practicing boxing|a man in a in <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>',
#  'a group of people pose for the camera in front of some laundry and greenery .|a man of people are in a camera . the of a . . white .',
#  'two girls are doing cartwheels as other children stand around watching .|a people in playing a in a in in in a the',
#  'two kids ride an amusement park ride .|a girls are in orange . . .',
#  'a boy wearing a helmet flips up his scooter as he skates between orange cones .|a man in a blue in on . mouth . a . . a . .',
#  'two women are looking at a monitor with a long antenna .|a people are playing a a street . a red . .',
#  'the number 52 motorcyclist in a blue and black helmet is going around a corner .|a man is is on a blue and white is a on on a bike .',
#  'a little girl holding hands with her ice skating instructor .|a man boy in a in a and and . .',
#  ...]

# %%
with open('predictions.txt','w') as f:
    f.writelines(combined)

# %%
for batch_idx, (imgs, captions, all_captions) in enumerate(val_loader):
    imgs, captions = imgs.to(device), captions.to(device)
    pred, alpha = model(imgs, captions)
    break

# %%
imgs.shape, captions.shape, all_captions

# %%
pred = pred.argmax(2)

# %%
def indices_to_words(indices, vocab, referenceCorpus):
    decoded_sentences = []
    count = 0 ; 
    for idx_row in indices:
        count += 1 
        sentence = []
    
        for idx in idx_row:
            word = vocab.get_word(idx.item())
            if(word == '<start>'):
                continue 
            if word == '<end>':  # Stop decoding if '<end>' token is encountered
                break
            sentence.append(word)
        if(referenceCorpus):
            corpus = []
            corpus.append(sentence)
            decoded_sentences.append(corpus)
        else: 
            decoded_sentences.append(sentence)
    # print("the loop runs for" , count)
    return decoded_sentences

# %%
indices_to_words(pred, val_dataset.vocab, False)

# %%
model = encoderDecoder.EncoderDecoderAttention(256, 256, len(val_dataset.vocab))
model.load_state_dict(torch.load("../model/model_epoch10.pth"))

# %%
pred, alpha = model(imgs, captions)
pred = pred.argmax(1)
indices_to_words(pred, val_dataset.vocab, False)

# %%
def generate_from_img(img_path, caption, transform, model, caption):
    img = Image.open(img_location).convert("RGB")
    img = transform(img)
    img.to(device)

# %%
predictions = []
for batch_idx, (imgs, captions, all_captions) in enumerate(val_loader):
    imgs, captions = imgs.to(device), captions.to(device)
    preds = generate_caption(imgs, captions, model)
    predictions.extend(preds)

# %%
a = torch.rand((1,3,6))
b = a.squeeze(0)

# %%
a

# %%
b

# %%
from PIL import Image

def pil_loader(path):
    with open(path, 'rb') as f:
        img = Image.open(f)
        return img.convert('RGB')

def generate_caption_visualization(encoder, decoder, img_path, vocab, beam_size=3, smooth=True):
    
    
    img = pil_loader(img_path)
    img = transform(img)
    img = torch.FloatTensor(img)
    img = img.unsqueeze(0)
    img = img.to(device)
    img_features = encoder(img)
    
    print(img_features.device)


    #img = img.to('cpu')
    #img_features = img_features.to('cpu')
    
    #print(decoder.weight.device)
    img_features = img_features.expand(beam_size, img_features.size(1), img_features.size(2))
    sentence, alpha = decoder.caption(img_features, beam_size)

    token_dict = vocab.idx2word
    sentence_tokens = []
    for word_idx in sentence:
        sentence_tokens.append(token_dict[word_idx])
        if word_idx == word_dict['<end>']:
            break

    img = Image.open(img_path)
    w, h = img.size
    if w > h:
        w = w * 256 / h
        h = 256
    else:
        h = h * 256 / w
        w = 256
    left = (w - 224) / 2
    top = (h - 224) / 2
    resized_img = img.resize((int(w), int(h)), Image.BICUBIC).crop((left, top, left + 224, top + 224))
    img = np.array(resized_img.convert('RGB').getdata()).reshape(224, 224, 3)
    img = img.astype('float32') / 255

    num_words = len(sentence_tokens)
    w = np.round(np.sqrt(num_words))
    h = np.ceil(np.float32(num_words) / w)
    alpha = torch.tensor(alpha)

    plot_height = ceil((num_words + 3) / 4.0)
    ax1 = plt.subplot(4, plot_height, 1)
    plt.imshow(img)
    plt.axis('off')
    for idx in range(num_words):
        ax2 = plt.subplot(4, plot_height, idx + 2)
        label = sentence_tokens[idx]
        plt.text(0, 1, label, backgroundcolor='white', fontsize=13)
        plt.text(0, 1, label, color='black', fontsize=13)
        plt.imshow(img)

        if encoder.network == 'vgg19':
            shape_size = 14
        else:
            shape_size = 7

        if smooth:
            alpha_img = skimage.transform.pyramid_expand(alpha[idx, :].reshape(shape_size, shape_size), upscale=16, sigma=20)
        else:
            alpha_img = skimage.transform.resize(alpha[idx, :].reshape(shape_size,shape_size), [img.shape[0], img.shape[1]])
        plt.imshow(alpha_img, alpha=0.8)
        plt.set_cmap(cm.Greys_r)
        plt.axis('off')
    plt.show()

# %%
with torch.no_grad():
    encoder = model.encoder.to(device)
    decoder = model.decoder.to(device)
    
    generate_caption_visualization(encoder, decoder, "../data/flickr8k/Images/997722733_0cb5439472.jpg", val_dataset.vocab)

# %%
# used for calculating bleu scores
references = []
hypotheses = []
with torch.no_grad():
    for batch_idx, (imgs, captions, all_captions) in enumerate(val_loader):
        # imgs, captions = Variable(imgs).cuda(), Variable(captions).cuda()
        imgs, captions = imgs.to(device), captions.to(device)
        preds, alphas = model(imgs, captions)
        targets = captions[:, 1:]

        targets = pack_padded_sequence(targets, [len(tar) - 1 for tar in targets], batch_first=True)[0]
        packed_preds = pack_padded_sequence(preds, [len(pred) - 1 for pred in preds], batch_first=True)[0]

        att_regularization = alpha_c * ((1 - alphas.sum(1))**2).mean()

        loss = cross_entropy_loss(packed_preds, targets)
        loss += att_regularization

        total_caption_length = calculate_caption_lengths(vocab, captions)
        acc1 = accuracy(packed_preds, targets, 1)
        acc5 = accuracy(packed_preds, targets, 5)
        losses.update(loss.item(), total_caption_length)
        top1.update(acc1, total_caption_length)
        top5.update(acc5, total_caption_length)

        start_token = vocab.get_index('<start>')
        pad_token = vocab.get_index('<pad>')
        for cap_set in all_captions.tolist():
            caps = []
            for caption in cap_set:
                cap = [word_idx for word_idx in caption
                                if word_idx != start_token and word_idx != pad_token]
                caps.append(cap)
            references.append(caps)

        word_idxs = torch.max(preds, dim=2)[1]
        for idxs in word_idxs.tolist():
            hypotheses.append([idx for idx in idxs
                                   if idx != start_token and idx != pad_token])

        if batch_idx % log_interval == 0:
            print('Validation Batch: [{0}/{1}]\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Top 1 Accuracy {top1.val:.3f} ({top1.avg:.3f})\t'
                  'Top 5 Accuracy {top5.val:.3f} ({top5.avg:.3f})'.format(
                      batch_idx, len(data_loader), loss=losses, top1=top1, top5=top5))
        print('References',references)
        print('Hypothesis')
